# %% [markdown]
# # 03: Evaluation
#
# In Notebook 02 we ran individual questions by hand. This notebook evaluates the agent
# systematically: we upload a dataset subset to Langfuse, run the agent on every item, and
# score each response with an LLM-as-judge grader using the official DeepSearchQA methodology.
#
# ## What You'll Learn
#
# 1. Uploading a DeepSearchQA subset to Langfuse as a persistent dataset
# 2. The LLM-as-judge grader: precision, recall, F1, and the four outcome categories
# 3. A single-sample evaluation walkthrough
# 4. Running the full experiment with `run_experiment`
# 5. Inspecting and interpreting item-level results
#
# ## Prerequisites
#
# Complete Notebooks 01 and 02. You'll need all credentials in `.env`:
# - `GOOGLE_API_KEY`
# - `LANGFUSE_PUBLIC_KEY` and `LANGFUSE_SECRET_KEY`
# - `OPENAI_API_KEY` (for the LLM grader)

# %%
import json
import os
import tempfile
from pathlib import Path
from typing import Any

import pandas as pd
from aieng.agent_evals.evaluation import run_experiment
from aieng.agent_evals.evaluation.graders.config import LLMRequestConfig
from aieng.agent_evals.knowledge_qa import BloombergFinancialNewsDataset, KnowledgeGroundedAgent
from aieng.agent_evals.knowledge_qa.bloombergfinance_grader import (
    EvaluationOutcome,
    evaluate_bloomberg_groundtruth_async,
)
from aieng.agent_evals.knowledge_qa.notebook import display_response, run_with_display
from aieng.agent_evals.langfuse import upload_dataset_to_langfuse
from dotenv import load_dotenv
from IPython.display import HTML, display  # noqa: A004
from langfuse.experiment import Evaluation
from rich.console import Console
from rich.panel import Panel
from rich.table import Table


# Set working directory to the repository root
if Path("").absolute().name == "eval-agents":
    print(f"Working directory: {Path('').absolute()}")
else:
    os.chdir(Path("").absolute().parent)
    print(f"Working directory set to: {Path('').absolute()}")

load_dotenv(verbose=True)

console = Console(width=100)

DATASET_NAME = "Bloomberg-Financial"
# Out:
# Working directory set to: /home/coder/eval-agents/implementations

# %%
dataset = BloombergFinancialNewsDataset()
dataset.sample(20)
# Out:
# 2026-03-25 15:57:44,913 INFO aieng.agent_evals.knowledge_qa.data.bloombergfinance: Loading golden eval data from /home/coder/eval-agents/aieng-eval-agents/aieng/agent_evals/knowledge_qa/data/golden_eval.json...
# 2026-03-25 15:57:44,926 INFO aieng.agent_evals.knowledge_qa.data.bloombergfinance: Loaded 30 golden eval examples
# [BloombergNewsExample(input='How many branches did TD Bank close in the United States in Q3 2013?', expected_output='This information is not available in the Bloomberg articles from August 27-30, 2013.', metadata=GoldenEvalMetadata(example_id=23, category='unanswerable', answer_type='Single Answer', bank='TD', question_type='unanswerable', source_date='N/A', source_headline='N/A - not covered in dataset')),
#  BloombergNewsExample(input="What was Bank of Montreal's Q3 2013 net income and how did it compare to the prior year?", expected_output='C$1.14 billion ($1.08 billion), or C$1.68 a share, up 17 percent from C$970 million, or C$1.42, a year earlier', metadata=GoldenEvalMetadata(example_id=3, category='earnings', answer_type='Single Answer', bank='BMO', question_type='single_article', source_date='2013-08-27', source_headline='Bank of Montreal Profit Tops Estimates on Consumer Loans')),
#  BloombergNewsExample(input='Who left Canadian Imperial Bank of Commerce for National Bank in August 2013?', expected_output='Hashimoto and Bhutani', metadata=GoldenEvalMetadata(example_id=11, category='personnel', answer_type='Set Answer', bank='CIBC', question_type='single_article', source_date='2013-08-30', source_headline='Hashimoto and Bhutani Leave Canadian Imperial for National Bank')),
#  BloombergNewsExample(input='Did any of the Big Five Canadian banks announce layoffs in August 2013?', expected_output='No layoff announcements from the Big Five banks are reported in the Bloomberg articles from August 27-30, 2013.', metadata=GoldenEvalMetadata(example_id=26, category='unanswerable', answer_type='Single Answer', bank='all', question_type='unanswerable', source_date='N/A', source_headline='N/A - not covered in dataset')),
#  BloombergNewsExample(input="What was BMO's provision for credit losses in Q3 2013 compared to Q2 2013?", expected_output='The exact Q2 comparison is not available, but BMO set aside less money for bad loans in Q3 2013 compared to the prior year.', metadata=GoldenEvalMetadata(example_id=25, category='unanswerable', answer_type='Single Answer', bank='BMO', question_type='unanswerable', source_date='N/A', source_headline='N/A - Q2 comparison not in dataset')),
#  BloombergNewsExample(input="What acquisition helped Scotiabank's Q3 2013 consumer lending results?", expected_output='The C$3.1 billion purchase of ING Direct Canada in November, which bolstered loans and added about 1.8 million customers', metadata=GoldenEvalMetadata(example_id=4, category='deals', answer_type='Single Answer', bank='Scotiabank', question_type='single_article', source_date='2013-08-27', source_headline='Scotiabank Profit Beats Estimates as ING Unit Bolsters Earnings')),
#  BloombergNewsExample(input="Which of Canada's Big Five banks raised their dividends in Q3 2013 and by how much?", expected_output='Royal Bank of Canada raised its dividend 6.3 percent to 67 cents, Toronto-Dominion raised 4.9 percent to 85 cents, and Bank of Nova Scotia raised 3.3 percent to 62 cents', metadata=GoldenEvalMetadata(example_id=14, category='comparative', answer_type='Set Answer', bank='all', question_type='multi_article', source_date='2013-08-27 to 2013-08-29', source_headline='Multiple earnings articles')),
#  BloombergNewsExample(input='Who was set to become the first female chairman of a Canadian bank?', expected_output="RBC's Taylor", metadata=GoldenEvalMetadata(example_id=10, category='personnel', answer_type='Single Answer', bank='RBC', question_type='single_article', source_date='2013-08-30', source_headline="RBC's Taylor to Be First Female Chairman of Canadian Bank")),
#  BloombergNewsExample(input="Why did Toronto-Dominion Bank's profit fall in Q3 2013?", expected_output='Insurance losses from severe weather claims, including flooding in southern Alberta in June and a record deluge in Toronto that submerged parts of the city on June 8', metadata=GoldenEvalMetadata(example_id=2, category='causal', answer_type='Single Answer', bank='TD', question_type='single_article', source_date='2013-08-29', source_headline='Toronto-Dominion Profit Falls 10% on Weather Insurance Costs')),
#  BloombergNewsExample(input="What was Royal Bank of Canada's Q4 2013 net income?", expected_output='This information is not available in the Bloomberg articles from late August 2013. Q4 2013 results had not been reported yet.', metadata=GoldenEvalMetadata(example_id=21, category='unanswerable', answer_type='Single Answer', bank='RBC', question_type='unanswerable', source_date='N/A', source_headline='N/A - Q4 results not yet reported')),
#  BloombergNewsExample(input='By how much did RBC and Scotiabank each raise their dividends in Q3 2013?', expected_output='RBC raised its dividend 6.3 percent to 67 cents a share. Scotiabank raised its dividend 3.3 percent to 62 cents a share.', metadata=GoldenEvalMetadata(example_id=28, category='comparative', answer_type='Single Answer', bank='all', question_type='multi_article', source_date='2013-08-27 to 2013-08-29', source_headline='RBC Tops Estimates; Scotiabank Profit Beats Estimates')),
#  BloombergNewsExample(input='How much in Aeroplan credit card loans was CIBC managing as TD negotiations continued?', expected_output='C$6 billion', metadata=GoldenEvalMetadata(example_id=8, category='deals', answer_type='Single Answer', bank='CIBC', question_type='single_article', source_date='2013-08-29', source_headline='CIBC Has C$6 Billion of Aerogold Card Loans as TD Talks Continue')),
#  BloombergNewsExample(input="What was the Bank of Canada's policy interest rate in August 2013 and was it expected to change?", expected_output='This specific information is not available in the Bloomberg articles from August 27-30, 2013. The articles discuss rising bond yields and interest rate expectations but do not state the policy rate.', metadata=GoldenEvalMetadata(example_id=30, category='unanswerable', answer_type='Single Answer', bank='all', question_type='unanswerable', source_date='N/A', source_headline='N/A - policy rate not explicitly stated in dataset')),
#  BloombergNewsExample(input="What was TD Bank's wealth-management and insurance unit profit in Q3 2013?", expected_output='C$7 million, down from C$360 million a year earlier', metadata=GoldenEvalMetadata(example_id=6, category='earnings', answer_type='Single Answer', bank='TD', question_type='single_article', source_date='2013-08-29', source_headline='Toronto-Dominion Profit Falls 10% on Weather Insurance Costs')),
#  BloombergNewsExample(input='Which Canadian Big Five bank reported the largest percentage profit increase in Q3 2013 and which reported a decline?', expected_output='Bank of Montreal reported the largest increase at 17 percent. Toronto-Dominion was the only bank to report a decline, with profit falling 10 percent due to weather insurance costs.', metadata=GoldenEvalMetadata(example_id=15, category='comparative', answer_type='Single Answer', bank='all', question_type='multi_article', source_date='2013-08-27 to 2013-08-29', source_headline='Multiple earnings articles')),
#  BloombergNewsExample(input='What were the Q3 2013 net incomes of all Big Five Canadian banks ranked from highest to lowest?', expected_output='RBC C$2.3 billion, Scotiabank C$1.77 billion, TD C$1.53 billion, BMO C$1.14 billion, CIBC C$890 million', metadata=GoldenEvalMetadata(example_id=20, category='comparative', answer_type='Single Answer', bank='all', question_type='multi_article', source_date='2013-08-27 to 2013-08-29', source_headline='Multiple earnings articles across all five banks')),
#  BloombergNewsExample(input="What were the combined profits of Canada's six biggest lenders in fiscal Q3 2013 and why were analysts optimistic about the outlook?", expected_output='Combined profits were C$8.05 billion ($7.6 billion), down 1.7 percent from a year earlier. Analysts were optimistic because rising interest rates were expected to make mortgages and car loans more profitable, with signs of emerging margin stability due to the increase in bond yields.', metadata=GoldenEvalMetadata(example_id=17, category='comparative', answer_type='Single Answer', bank='all', question_type='multi_article', source_date='2013-08-30', source_headline="Canada Banks' Profits Poised to Rally as Rates Rise")),
#  BloombergNewsExample(input="What was BMO's Q3 2013 revenue?", expected_output='C$4.05 billion, up 4.4 percent from a year earlier', metadata=GoldenEvalMetadata(example_id=12, category='earnings', answer_type='Single Answer', bank='BMO', question_type='single_article', source_date='2013-08-27', source_headline='Bank of Montreal Profit Tops Estimates on Consumer Loans')),
#  BloombergNewsExample(input="What was Scotiabank's exposure to emerging market debt in Q3 2013?", expected_output='This information is not available in the Bloomberg articles from August 27-30, 2013.', metadata=GoldenEvalMetadata(example_id=24, category='unanswerable', answer_type='Single Answer', bank='Scotiabank', question_type='unanswerable', source_date='N/A', source_headline='N/A - not covered in dataset')),
#  BloombergNewsExample(input="What was CIBC's credit rating from Moody's in August 2013?", expected_output='This information is not available in the Bloomberg articles from August 27-30, 2013.', metadata=GoldenEvalMetadata(example_id=22, category='unanswerable', answer_type='Single Answer', bank='CIBC', question_type='unanswerable', source_date='N/A', source_headline='N/A - not covered in dataset'))]

# %% [markdown]
# ## 1. Uploading the Dataset to Langfuse
#
# Langfuse stores our evaluation dataset so we can run multiple experiments against the same items
# and compare results over time. Each dataset item has three fields:
#
# - **`input`**: the question (sent to the agent)
# - **`expected_output`**: the ground truth answer (given to the grader, never shown to the agent)
# - **`metadata`**: `category`, `answer_type`, `example_id`
#
# Items are deduplicated by a hash of their content, so running this cell again is safe.

# %%
# dataset = BloombergFinancialNewsDataset()
# # examples = dataset.get_by_category("Finance & Economics")[:1]
# examples = dataset.sample(20)
# console.print(f"Uploading [cyan]{len(examples)}[/cyan] examples to dataset '{DATASET_NAME}'...")

# # Write examples to a temporary JSONL file for the upload utility
# with tempfile.NamedTemporaryFile(mode="w", suffix=".jsonl", delete=False, encoding="utf-8") as f:
#     for ex in examples:
#         record = {
#             "input": ex.problem,
#             "expected_output": ex.answer,
#             "metadata": {
#                 "example_id": ex.example_id,
#                 "category": ex.problem_category,
#                 "answer_type": ex.answer_type,
#             },
#         }
#         f.write(json.dumps(record, ensure_ascii=False) + "\n")
#     temp_path = f.name

temp_path = "/home/coder/eval-agents/aieng-eval-agents/aieng/agent_evals/knowledge_qa/data/golden_eval.json"
await upload_dataset_to_langfuse(dataset_path=temp_path, dataset_name=DATASET_NAME)
# os.unlink(temp_path)

# console.print(f"[green]✓[/green] Dataset '{DATASET_NAME}' ready in Langfuse")
# Out:
# 2026-03-25 15:51:05,598 INFO aieng.agent_evals.langfuse: Loading dataset from '/home/coder/eval-agents/aieng-eval-agents/aieng/agent_evals/knowledge_qa/data/golden_eval.json'
# Uploading Langfuse dataset 'Bloomberg-Financial' ━━━━━━━━━ 30/30 0:00:00 0:00:0100:0100:01
# 2026-03-25 15:51:07,765 INFO aieng.agent_evals.langfuse: Uploaded 30 items to dataset 'Bloomberg-Financial'

# %% [markdown]
# ## 2. The Bloomberg Grader
#
# The grader is an LLM-as-judge that evaluates answers using the official Bloomberg methodology
# from Appendix A of the paper. It handles both answer types:
#
# - **Single Answer**: checks whether the response contains the one expected value
# - **Set Answer**: checks which items from the ground truth set appear in the response,
#   and flags any extra items the agent included
#
# ### Metrics
#
# Let **S** = predicted items, **G** = ground truth items:
#
# | Metric | Formula | Meaning |
# |--------|---------|---------|
# | **Precision** | \|S∩G\| / \|S\| | Of what the agent said, how much was correct |
# | **Recall** | \|S∩G\| / \|G\| | Of the ground truth, how much did the agent find |
# | **F1** | 2·P·R / (P+R) | Harmonic mean of precision and recall |
#
# ### Outcome Classification
#
# | Outcome | Condition | Interpretation |
# |---------|-----------|----------------|
# | `fully_correct` | S = G | Perfect answer |
# | `correct_with_extraneous` | G ⊆ S | All correct, but extra items included |
# | `partially_correct` | S∩G ≠ ∅ | Some correct items found |
# | `fully_incorrect` | S∩G = ∅ | No correct items |

# %% [markdown]
# ### 2.1 Single-Sample Walkthrough
#
# Before running at scale, let's walk through one example end-to-end: run the agent,
# then grade its response with the LLM judge.

# %%
# Pick one example for the walkthrough
example = dataset[15]

console.print(
    Panel(
        f"[bold]ID:[/bold] {example.metadata.example_id}\n"
        f"[bold]Category:[/bold] {example.metadata.category}\n"
        f"[bold]Answer Type:[/bold] {example.metadata.answer_type}\n"
        f"[bold]Bank:[/bold] {example.metadata.bank}\n\n"
        f"[bold cyan]Question:[/bold cyan]\n{example.input}\n\n"
        f"[bold yellow]Ground Truth:[/bold yellow]\n{example.expected_output}",
        title="Golden Evaluation Example",
        border_style="blue",
    )
)
# Out:
# ╭─────────────────────────────────── Golden Evaluation Example ────────────────────────────────────╮
# │ ID: 16                                                                                           │
# │ Category: comparative                                                                            │
# │ Answer Type: Single Answer                                                                       │
# │ Bank: all                                                                                        │
# │                                                                                                  │
# │ Question:                                                                                        │
# │ Both BMO and Scotiabank in Q3 2013 reported record profits in which business segments?           │
# │                                                                                                  │
# │ Ground Truth:                                                                                    │
# │ Both banks posted record results in Canadian consumer lending and wealth management              │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
eval_agent = KnowledgeGroundedAgent(enable_planning=True)
eval_response = await run_with_display(eval_agent, example.input)

display_response(
    console,
    eval_response.text,
    title="Agent Answer",
    subtitle=f"Duration: {eval_response.total_duration_ms / 1000:.1f}s  |  Tools: {len(eval_response.tool_calls)}",
)
# Out:
# <div style="max-width: 800px;">
# <div style="padding: 10px; background: #cfe2ff; border-radius: 8px; margin-bottom: 8px;"><b>Question:</b> Both BMO and Scotiabank in Q3 2013 reported record profits in which business segments?</div>
# <div style="font-family: monospace; padding: 10px; background: #e9ecef; border-radius: 8px; margin-top: 8px;">
# <div style="font-weight: bold; margin-bottom: 8px;">🔧 Tool Calls (8)</div>
# <div style="margin: 2px 0;"><span style="color: #28a745;">✓</span> 🔍 <b>google_search</b> <span style="color: #6c757d;">{'query': 'BMO Q3 2013 record profits business segments'}</span></div>
# <div style="margin: 2px 0;"><span style="color: #28a745;">✓</span> 🔍 <b>google_search</b> <span style="color: #6c757d;">{'query': 'Scotiabank Q3 2013 record profits business seg...</span></div>
# <div style="margin: 2px 0;"><span style="color: #28a745;">✓</span> 🌐 <b>web_fetch</b> <span style="color: #6c757d;">{'url': 'https://www.scotiabank.com/content/dam/scotiaban...</span></div>
# <div style="margin: 2px 0;"><span style="color: #28a745;">✓</span> 🔍 <b>google_search</b> <span style="color: #6c757d;">{'query': 'BMO Q3 2013 earnings press release'}</span></div>
# <div style="margin: 2px 0;"><span style="color: #28a745;">✓</span> 🔍 <b>google_search</b> <span style="color: #6c757d;">{'query': 'Scotiabank Q3 2013 earnings press release'}</span></div>
# <div style="margin: 2px 0;"><span style="color: #28a745;">✓</span> 🔍 <b>google_search</b> <span style="color: #6c757d;">{'query': 'BMO Q3 2013 earnings record profits business s...</span></div>
# <div style="margin: 2px 0;"><span style="color: #28a745;">✓</span> 🔍 <b>google_search</b> <span style="color: #6c757d;">{'query': 'BMO Q3 2013 record profits business segments'}</span></div>
# <div style="margin: 2px 0;"><span style="color: #28a745;">✓</span> 🔍 <b>google_search</b> <span style="color: #6c757d;">{'query': 'Scotiabank Q3 2013 record profits business seg...</span></div>
# </div>
# </div><div style="margin-top: 12px; padding: 10px; background: #d4edda; border-radius: 8px;">✓ Complete in 484.3s | 2 tool calls | 5 sources</div>
# ╭────────────────────────────────────────── Agent Answer ──────────────────────────────────────────╮
# │ In Q3 2013, BMO reported record profits in its Personal & Commercial Banking Canada and Private  │
# │ Client Group business segments. Scotiabank reported record earnings in its Canadian Banking      │
# │ business segment for the second consecutive quarter.                                             │
# ╰───────────────────────────────── Duration: 484.3s  |  Tools: 2 ──────────────────────────────────╯
# ╭─────────────────────────────────────────── Reasoning ────────────────────────────────────────────╮
# │ For BMO, the search summary for "BMO Q3 2013 record profits business segments" explicitly        │
# │ stated: "The business segments that significantly contributed to BMO's positive performance in   │
# │ Q3 2013 include: Personal & Commercial Banking Canada: This segment saw its earnings reach 'new  │
# │ highs'. Private Client Group: This group posted 'record earnings' in traditional wealth, showing │
# │ a 37% increase year-over-year."                                                                  │
# │                                                                                                  │
# │ For Scotiabank, the search summary for "Scotiabank Q3 2013 record profits business segments"     │
# │ stated: "Scotiabank's Canadian Banking segment did achieve a second consecutive quarter of       │
# │ record earnings, with net income reaching $593 million in Q3 2013." The summary also clarified   │
# │ that the overall net income for Scotiabank in Q3 2013 was not a record compared to Q3 2012.      │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
console.print("[dim]Grading with LLM judge against ground truth...[/dim]\n")

result = await evaluate_bloomberg_groundtruth_async(
    question=example.input,
    answer=eval_response.text,
    ground_truth=example.expected_output,
    answer_type=example.metadata.answer_type,
    model_config=LLMRequestConfig(temperature=0.0),
)

outcome_color = {
    EvaluationOutcome.FULLY_CORRECT: "green",
    EvaluationOutcome.CORRECT_WITH_EXTRANEOUS: "yellow",
    EvaluationOutcome.PARTIALLY_CORRECT: "orange1",
    EvaluationOutcome.FULLY_INCORRECT: "red",
}.get(result.outcome, "white")

metrics_table = Table(title="Grader Results")
metrics_table.add_column("Metric", style="cyan")
metrics_table.add_column("Value", style="white")
metrics_table.add_row("Outcome", f"[{outcome_color}]{result.outcome.value}[/{outcome_color}]")
metrics_table.add_row("Precision", f"{result.precision:.3f}")
metrics_table.add_row("Recall", f"{result.recall:.3f}")
metrics_table.add_row("F1", f"[bold]{result.f1_score:.3f}[/bold]")
console.print(metrics_table)

if result.explanation:
    console.print(Panel(result.explanation, title="Grader Explanation", border_style="magenta"))

# Show per-item correctness for Set Answer questions
if result.correctness_details:
    details_table = Table(title="Correctness Details")
    details_table.add_column("Expected Item", style="white")
    details_table.add_column("Found", style="cyan", justify="center")
    for item, found in result.correctness_details.items():
        icon = "[green]\u2713[/green]" if found else "[red]\u2717[/red]"
        label = item[:60] + "..." if len(item) > 60 else item
        details_table.add_row(label, icon)
    console.print(details_table)
# Out:
# Grading with LLM judge against ground truth...
#        Grader Results
# ┏━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Metric    ┃ Value         ┃
# ┡━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Outcome   │ fully_correct │
# │ Precision │ 1.000         │
# │ Recall    │ 1.000         │
# │ F1        │ 1.000         │
# └───────────┴───────────────┘
# ╭─────────────────────────────────────── Grader Explanation ───────────────────────────────────────╮
# │ The AI correctly identifies the business segments for both banks that correspond to the ground   │
# │ truth answer. BMO's 'Personal & Commercial Banking Canada' and Scotiabank's 'Canadian Banking'   │
# │ align with 'Canadian consumer lending'. BMO's 'Private Client Group' aligns with 'wealth         │
# │ management'.                                                                                     │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
#                             Correctness Details
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Expected Item                                                   ┃ Found ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━┩
# │ Both banks posted record results in Canadian consumer lendin... │   ✓   │
# └─────────────────────────────────────────────────────────────────┴───────┘

# %% [markdown]
# ## 3. Running the Evaluation Experiment
#
# `run_experiment` runs the agent against every item in the Langfuse dataset, scores each
# response, and records results in Langfuse. Each call creates a new named experiment run
# that you can compare to previous runs in the UI.
#
# The experiment takes two functions:
#
# - **`agent_task`** — receives a dataset item, runs the agent, returns the answer string
# - **`deepsearchqa_evaluator`** — receives question, answer, and ground truth; returns grader scores
#
# > **Note:** This makes one agent call and one grader call per item. With 10 items and
# > `max_concurrency=1`, expect 20–40 minutes depending on model latency.

# %%
async def agent_task(*, item: Any, **kwargs: Any) -> str:
    """Run the Knowledge Agent on a Langfuse dataset item."""
    agent = KnowledgeGroundedAgent(enable_planning=True)
    response = await agent.answer_async(item.input)
    return response.text


async def bloomberg_groundtruth_evaluator(
    *,
    input: str,  # noqa: A002
    output: str,
    expected_output: str,
    metadata: dict[str, Any] | None = None,
    **kwargs: Any,
) -> list[Evaluation]:
    """LLM-as-judge grader comparing agent answer to ground truth."""
    answer_type = (metadata or {}).get("answer_type", "Single Answer")
    result = await evaluate_bloomberg_groundtruth_async(
        question=input,
        answer=output,
        ground_truth=expected_output,
        answer_type=answer_type,
        model_config=LLMRequestConfig(temperature=0.0),
    )
    return result.to_evaluations()

# %%
experiment_result = run_experiment(
    DATASET_NAME,
    name="knowledge-agent-baseline",
    task=agent_task,
    evaluators=[bloomberg_groundtruth_evaluator],
    description="Baseline Knowledge Agent on August 2013 News questions.",
    max_concurrency=5,
)

console.print("[green]✓[/green] Experiment complete")
if experiment_result.dataset_run_url:
    display(
        HTML(
            f'<p>View experiment: <a href="{experiment_result.dataset_run_url}" target="_blank">{experiment_result.dataset_run_url}</a></p>'
        )
    )
# Out:
# 2026-03-25 15:57:59,993 WARNING langfuse: Propagated attribute 'experiment_item_metadata' value is over 200 characters (231 chars). Dropping value.
# 2026-03-25 15:58:00,292 INFO aieng.agent_evals.knowledge_qa.agent: Answering question: What was the Bank of Canada's policy interest rate in August 2013 and was it expected to change?...
# /home/coder/eval-agents/.venv/lib/python3.12/site-packages/google/adk/models/google_llm.py:172: UserWarning: [EXPERIMENTAL] GeminiContextCacheManager: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   cache_manager = GeminiContextCacheManager(self.api_client)
# 2026-03-25 15:58:00,621 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-25 15:58:06,328 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-25 15:58:06,329 WARNING google_genai.types: Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# 2026-03-25 15:58:06,333 INFO aieng.agent_evals.knowledge_qa.agent: Extracted plan with 5 steps
# 2026-03-25 15:58:06,334 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'Bank of Canada policy interest rate August 2013'})
# 2026-03-25 15:58:06,444 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 15:58:10,620 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-25 15:58:11,149 INFO google_adk.google.adk.models.gemini_context_cache_manager: Cache created successfully: cachedContents/zprof9xn31oysbi5o6v2bc95g8df0ch7i9ud2pzr
# 2026-03-25 15:58:11,153 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-25 15:58:11,155 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 15:58:12,538 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-25 15:58:12,541 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: web_fetch({'url': 'https://www.bankofcanada.ca/2013/09/fad-press-release-2013-09-04/', 'query': 'Bank of Canada policy interest rate August 2013 and expectations for change'})
# 2026-03-25 15:58:13,011 INFO aieng.agent_evals.tools.web: Fetched 55003 chars from https://www.bankofcanada.ca/2013/09/fad-press-release-2013-09-04/, extracting info...
# 2026-03-25 15:58:15,790 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: web_fetch completed
# 2026-03-25 15:58:15,920 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-25 15:58:15,922 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 15:58:18,215 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-25 15:58:18,257 WARNING langfuse: Propagated attribute 'experiment_item_metadata' value is over 200 characters (231 chars). Dropping value.
# 2026-03-25 15:58:30,772 WARNING langfuse: Propagated attribute 'experiment_item_metadata' value is over 200 characters (270 chars). Dropping value.
# 2026-03-25 15:58:30,950 INFO aieng.agent_evals.knowledge_qa.agent: Answering question: What was Canada's second-quarter GDP growth rate in 2013 and how did it affect expectations for the ...
# 2026-03-25 15:58:31,080 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-25 15:58:40,553 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-25 15:58:40,556 INFO aieng.agent_evals.knowledge_qa.agent: Extracted plan with 4 steps
# 2026-03-25 15:58:40,557 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'Canada Q2 2013 GDP growth rate'})
# 2026-03-25 15:58:40,672 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 15:59:06,758 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-25 15:59:07,269 INFO google_adk.google.adk.models.gemini_context_cache_manager: Cache created successfully: cachedContents/0q2b3l47ie3wzmyv3sf40pibqwwraie3kklthu1x
# 2026-03-25 15:59:07,272 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-25 15:59:07,273 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 15:59:08,594 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-25 15:59:08,597 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'Canada Q2 2013 GDP impact on bank expectations'})
# 2026-03-25 15:59:08,718 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 15:59:31,863 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-25 15:59:31,977 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-25 15:59:31,978 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 15:59:35,137 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-25 15:59:35,139 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: web_fetch({'url': 'https://www150.statcan.gc.ca/n1/daily-quotidien/130830/dq130830a-eng.htm', 'query': "Canada's real GDP growth rate for Q2 2013, including initial and revised figures, and the annualized rate."})
# 2026-03-25 15:59:35,377 INFO aieng.agent_evals.tools.web: Fetched 25104 chars from https://www150.statcan.gc.ca/n1/daily-quotidien/130830/dq130830a-eng.htm, extracting info...
# 2026-03-25 15:59:38,279 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: web_fetch completed
# 2026-03-25 15:59:38,391 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-25 15:59:38,392 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 15:59:40,046 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-25 15:59:40,049 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: web_fetch({'url': 'https://www150.statcan.gc.ca/n1/pub/11-626-x/11-626-x2013030-eng.htm', 'query': "Canada's real GDP growth rate for Q2 2013, including initial and revised figures, and the annualized rate."})
# 2026-03-25 15:59:40,250 INFO aieng.agent_evals.tools.web: Fetched 24672 chars from https://www150.statcan.gc.ca/n1/pub/11-626-x/11-626-x2013030-eng.htm, extracting info...
# 2026-03-25 15:59:42,998 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: web_fetch completed
# 2026-03-25 15:59:43,114 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-25 15:59:43,116 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 15:59:48,992 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-25 15:59:48,995 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'Canada Q2 2013 GDP growth rate'})
# 2026-03-25 15:59:49,103 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 15:59:53,024 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-25 15:59:53,137 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-25 15:59:53,139 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 15:59:54,251 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-25 15:59:54,254 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'Canada Q2 2013 GDP impact on bank expectations'})
# 2026-03-25 15:59:54,369 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 16:00:33,313 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-25 16:00:33,439 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-25 16:00:33,441 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 16:00:40,920 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-25 16:00:40,964 WARNING langfuse: Propagated attribute 'experiment_item_metadata' value is over 200 characters (270 chars). Dropping value.
# 2026-03-25 16:00:57,900 WARNING langfuse: Propagated attribute 'experiment_item_metadata' value is over 200 characters (255 chars). Dropping value.
# 2026-03-25 16:00:58,093 INFO aieng.agent_evals.knowledge_qa.agent: Answering question: By how much did RBC and Scotiabank each raise their dividends in Q3 2013?...
# 2026-03-25 16:00:58,212 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-25 16:01:05,196 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-25 16:01:05,198 INFO aieng.agent_evals.knowledge_qa.agent: Extracted plan with 5 steps
# 2026-03-25 16:01:05,199 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'RBC dividend increase Q3 2013'})
# 2026-03-25 16:01:05,312 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 16:01:09,936 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-25 16:01:10,502 INFO google_adk.google.adk.models.gemini_context_cache_manager: Cache created successfully: cachedContents/4c6366a4xpvx2r38xry8deumxd5c87zluzejc78r
# 2026-03-25 16:01:10,504 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-25 16:01:10,505 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 16:01:11,969 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-25 16:01:11,971 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: web_fetch({'url': 'https://www.rbc.com/investor-relations/_assets-custom/pdf/q32013release.pdf', 'query': 'RBC quarterly common share dividend increase Q3 2013'})
# 2026-03-25 16:01:12,376 INFO aieng.agent_evals.tools.web: Extracted 20550 chars from PDF (4 pages), extracting info...
# 2026-03-25 16:01:14,452 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: web_fetch completed
# 2026-03-25 16:01:14,567 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-25 16:01:14,568 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 16:01:15,801 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-25 16:01:15,804 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'Scotiabank dividend increase Q3 2013'})
# 2026-03-25 16:01:15,914 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 16:01:22,740 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-25 16:01:22,850 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-25 16:01:22,852 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 16:01:24,262 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-25 16:01:24,264 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: web_fetch({'query': 'Scotiabank quarterly common share dividend increase Q3 2013', 'url': 'https://www.scotiabank.com/ca/en/files/13/12/BNS_2013_Annual_Report.pdf'})
# 2026-03-25 16:01:24,761 INFO aieng.agent_evals.tools.web: Extracted 28497 chars from PDF (200 pages), extracting info...
# 2026-03-25 16:01:27,541 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: web_fetch completed
# 2026-03-25 16:01:27,648 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-25 16:01:27,649 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 16:01:30,733 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-25 16:01:30,736 INFO aieng.agent_evals.knowledge_qa.agent: Replanned with 5 new steps (keeping 3 completed)
# 2026-03-25 16:01:30,736 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'Scotiabank Q3 2013 earnings release dividend'})
# 2026-03-25 16:01:30,847 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 16:01:34,339 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-25 16:01:34,454 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-25 16:01:34,455 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 16:01:35,786 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-25 16:01:35,788 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: web_fetch({'query': 'Scotiabank dividend increase amount and new dividend per share in Q3 2013 earnings release', 'url': 'https://www.advisor.ca/industry-news/industry/scotiabank-reports-q3-profit-of-1-98b/'})
# 2026-03-25 16:01:36,281 INFO aieng.agent_evals.tools.web: Fetched 49775 chars from https://www.advisor.ca/industry-news/industry/scotiabank-reports-q3-profit-of-1-98b/, extracting info...
# 2026-03-25 16:01:38,524 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: web_fetch completed
# 2026-03-25 16:01:38,642 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-25 16:01:38,643 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 16:01:41,373 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-25 16:01:41,376 INFO aieng.agent_evals.knowledge_qa.agent: Replanned with 5 new steps (keeping 5 completed)
# 2026-03-25 16:01:41,377 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'Scotiabank press release Q3 2013 dividend'})
# 2026-03-25 16:01:41,487 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 16:01:49,784 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-25 16:01:49,898 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-25 16:01:49,900 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 16:01:52,413 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-25 16:01:52,417 INFO aieng.agent_evals.knowledge_qa.agent: Replanned with 5 new steps (keeping 6 completed)
# 2026-03-25 16:01:52,418 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'Scotiabank dividend increase announced Q3 2013'})
# 2026-03-25 16:01:52,528 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 16:01:58,577 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-25 16:01:58,692 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-25 16:01:58,693 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 16:02:00,169 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-25 16:02:00,172 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: web_fetch({'query': 'Scotiabank dividend history 2013, specifically Q3 dividend increase amount and previous dividend amount', 'url': 'https://www.dividendmax.com/canada/toronto-stock-exchange/banks/bank-of-nova-scotia/dividends'})
# 2026-03-25 16:02:01,168 INFO aieng.agent_evals.tools.web: Fetched 13819 chars from https://www.dividendmax.com/canada/toronto-stock-exchange/banks/bank-of-nova-scotia/dividends, extracting info...
# 2026-03-25 16:02:04,243 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: web_fetch completed
# 2026-03-25 16:02:04,357 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-25 16:02:04,358 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 16:02:07,001 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-25 16:02:07,046 WARNING langfuse: Propagated attribute 'experiment_item_metadata' value is over 200 characters (255 chars). Dropping value.
# 2026-03-25 16:02:19,453 WARNING langfuse: Propagated attribute 'experiment_item_metadata' value is over 200 characters (214 chars). Dropping value.
# 2026-03-25 16:02:19,617 INFO aieng.agent_evals.knowledge_qa.agent: Answering question: What was the share price performance of Big Five Canadian bank stocks relative to the S&P/TSX Financ...
# 2026-03-25 16:02:19,732 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-25 16:02:21,646 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-25 16:02:21,648 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'Canadian Big Five banks stock performance August 27-30 2013 S&P/TSX Financials Index'})
# 2026-03-25 16:02:21,760 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 16:03:34,290 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-25 16:03:34,971 INFO google_adk.google.adk.models.gemini_context_cache_manager: Cache created successfully: cachedContents/efpunazpn02aut9urb8bhjzyqpyokfmur8mkl06f
# 2026-03-25 16:03:34,974 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-25 16:03:34,974 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 16:03:42,662 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-25 16:03:42,703 WARNING langfuse: Propagated attribute 'experiment_item_metadata' value is over 200 characters (214 chars). Dropping value.
# 2026-03-25 16:03:57,113 WARNING langfuse: Propagated attribute 'experiment_item_metadata' value is over 200 characters (209 chars). Dropping value.
# 2026-03-25 16:03:57,285 INFO aieng.agent_evals.knowledge_qa.agent: Answering question: Did any of the Big Five Canadian banks announce layoffs in August 2013?...
# 2026-03-25 16:03:57,396 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-25 16:03:59,030 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-25 16:03:59,033 INFO aieng.agent_evals.knowledge_qa.agent: Extracted plan with 5 steps
# 2026-03-25 16:03:59,034 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'Canadian Big Five banks layoffs August 2013'})
# 2026-03-25 16:03:59,150 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 16:04:11,556 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-25 16:04:12,198 INFO google_adk.google.adk.models.gemini_context_cache_manager: Cache created successfully: cachedContents/67joxcflfkk7gc6q4im9crakl0swd7os9ym46z6t
# 2026-03-25 16:04:12,201 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-25 16:04:12,203 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 16:04:15,331 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-25 16:04:15,334 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: web_fetch({'url': 'https://www.cbc.ca/news/business/bmo-cut-1-000-jobs-in-last-quarter-1.2448862', 'query': 'when did BMO announce the job cuts and when did they occur'})
# 2026-03-25 16:04:15,335 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: web_fetch({'query': 'when did BMO announce the job cuts and when did they occur', 'url': 'https://www.cbc.ca/news/business/bmo-job-cuts-have-little-to-do-with-sky-high-profits-1.2450825'})
# 2026-03-25 16:07:18,720 ERROR aieng.agent_evals.tools.web: Failed to fetch https://www.cbc.ca/news/business/bmo-cut-1-000-jobs-in-last-quarter-1.2448862 after 3 retries:
# 2026-03-25 16:07:18,740 ERROR aieng.agent_evals.tools.web: Failed to fetch https://www.cbc.ca/news/business/bmo-job-cuts-have-little-to-do-with-sky-high-profits-1.2450825 after 3 retries:
# 2026-03-25 16:07:18,743 WARNING aieng.agent_evals.knowledge_qa.agent: Tool error: web_fetch failed - Failed after 3 retries:
# 2026-03-25 16:07:18,745 WARNING aieng.agent_evals.knowledge_qa.agent: Tool error: web_fetch failed - Failed after 3 retries:
# 2026-03-25 16:07:18,865 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-25 16:07:18,866 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 16:07:23,704 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-25 16:07:23,749 WARNING langfuse: Propagated attribute 'experiment_item_metadata' value is over 200 characters (209 chars). Dropping value.
# 2026-03-25 16:07:34,314 WARNING langfuse: Propagated attribute 'experiment_item_metadata' value is over 200 characters (215 chars). Dropping value.
# 2026-03-25 16:07:34,481 INFO aieng.agent_evals.knowledge_qa.agent: Answering question: What was BMO's provision for credit losses in Q3 2013 compared to Q2 2013?...
# 2026-03-25 16:07:34,595 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-25 16:07:36,925 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-25 16:07:36,928 INFO aieng.agent_evals.knowledge_qa.agent: Extracted plan with 5 steps
# 2026-03-25 16:07:36,929 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'BMO Q3 2013 earnings release provision for credit losses'})
# 2026-03-25 16:07:37,062 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 16:09:22,276 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b2582f88e00 state=finished raised ReadTimeout>]
# 2026-03-25 16:09:22,285 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-25 16:09:22,777 INFO google_adk.google.adk.models.gemini_context_cache_manager: Cache created successfully: cachedContents/co3nzzhcy3jo1mnk0f6joezxu8mta1cnumr3ct3b
# 2026-03-25 16:09:22,780 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-25 16:09:22,781 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 16:09:24,025 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-25 16:09:24,027 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'BMO Q3 2013 earnings release official'})
# 2026-03-25 16:09:24,162 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 16:11:02,831 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b2582ead670 state=finished raised ReadTimeout>]
# 2026-03-25 16:11:02,926 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b2582e9e0f0 state=finished raised ReadTimeout>]
# 2026-03-25 16:11:02,950 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b25a0e03620 state=finished raised ReadTimeout>]
# 2026-03-25 16:11:02,958 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-25 16:11:03,072 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-25 16:11:03,074 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 16:11:04,137 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-25 16:11:04,139 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'BMO investor relations Q3 2013 earnings report'})
# 2026-03-25 16:11:04,255 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 16:12:44,372 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b2582e6b7d0 state=finished raised ReadTimeout>]
# 2026-03-25 16:12:44,374 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b2582e5ae40 state=finished raised ReadTimeout>]
# 2026-03-25 16:12:44,391 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b2582e58e60 state=finished raised ReadTimeout>]
# 2026-03-25 16:12:44,405 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-25 16:12:44,523 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-25 16:12:44,525 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 16:12:45,563 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-25 16:12:45,565 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'BMO 2013 Q3 Q2 financial statements SEDAR'})
# 2026-03-25 16:12:45,679 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 16:14:24,236 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b2582f23e30 state=finished raised ReadTimeout>]
# 2026-03-25 16:14:24,238 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b25a2722d80 state=finished raised ReadTimeout>]
# 2026-03-25 16:14:24,247 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-25 16:14:24,363 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-25 16:14:24,365 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 16:14:25,348 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-25 16:14:25,350 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'SEDAR BMO financial statements 2013'})
# 2026-03-25 16:14:25,459 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 16:16:04,033 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b2582e94320 state=finished raised ReadTimeout>]
# 2026-03-25 16:16:04,035 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b25a2766b70 state=finished raised ReadTimeout>]
# 2026-03-25 16:16:04,129 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b2582e97560 state=finished raised ReadTimeout>]
# 2026-03-25 16:16:04,137 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-25 16:16:04,257 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-25 16:16:04,258 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 16:16:05,685 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-25 16:16:05,688 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'SEDAR BMO Q3 2013 interim consolidated financial statements'})
# 2026-03-25 16:16:05,802 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 16:17:43,654 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b2582ead0a0 state=finished raised ReadTimeout>]
# 2026-03-25 16:17:43,662 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-25 16:17:43,783 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-25 16:17:43,784 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 16:17:45,254 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-25 16:17:45,257 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: web_fetch({'url': 'https://www.sec.gov/Archives/edgar/data/927971/000119312516786447/d252647dex992.htm', 'query': 'BMO provision for credit losses for the three months ended July 31, 2013 and April 30, 2013'})
# 2026-03-25 16:17:47,277 INFO aieng.agent_evals.tools.web: Fetched 200035 chars from https://www.sec.gov/Archives/edgar/data/927971/000119312516786447/d252647dex992.htm, extracting info...
# 2026-03-25 16:17:52,061 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: web_fetch completed
# 2026-03-25 16:17:52,178 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-25 16:17:52,179 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 16:17:53,476 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-25 16:17:53,478 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'BMO Q3 2013 Report to Shareholders SEDAR'})
# 2026-03-25 16:17:53,590 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 16:19:33,766 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b25a27a4b60 state=finished raised ReadTimeout>]
# 2026-03-25 16:19:33,768 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b25b11af920 state=finished raised ReadTimeout>]
# 2026-03-25 16:19:33,776 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-25 16:19:33,892 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-25 16:19:33,893 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 16:19:34,762 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-25 16:19:34,764 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'site:sedar.com BMO interim consolidated financial statements Q3 2013'})
# 2026-03-25 16:19:34,868 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 16:21:12,651 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b2582e5b590 state=finished raised ReadTimeout>]
# 2026-03-25 16:21:12,661 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b25a27f9880 state=finished raised ReadTimeout>]
# 2026-03-25 16:21:12,670 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-25 16:21:12,787 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-25 16:21:12,788 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 16:21:13,755 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-25 16:21:13,757 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'BMO investor relations quarterly reports 2013'})
# 2026-03-25 16:21:13,868 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 16:22:54,020 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b2582528ce0 state=finished raised ReadTimeout>]
# 2026-03-25 16:22:54,022 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b2582521580 state=finished raised ReadTimeout>]
# 2026-03-25 16:22:54,090 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b2582e87830 state=finished raised ReadTimeout>]
# 2026-03-25 16:22:54,116 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b2582ea33e0 state=finished raised ReadTimeout>]
# 2026-03-25 16:22:54,128 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b258252b5c0 state=finished raised ReadTimeout>]
# 2026-03-25 16:22:54,134 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b2582ea3410 state=finished raised ReadTimeout>]
# 2026-03-25 16:22:54,150 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b258252b8c0 state=finished raised ReadTimeout>]
# 2026-03-25 16:22:54,163 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b2582ea3140 state=finished raised ReadTimeout>]
# 2026-03-25 16:22:54,175 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-25 16:22:54,295 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-25 16:22:54,297 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 16:22:56,528 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-25 16:22:56,533 WARNING aieng.agent_evals.knowledge_qa.agent: Empty model response (attempt 1/3), creating fresh session and retrying...
# 2026-03-25 16:22:56,649 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-25 16:22:58,463 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-25 16:22:58,466 INFO aieng.agent_evals.knowledge_qa.agent: Extracted plan with 6 steps
# 2026-03-25 16:22:58,467 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'BMO Q3 2013 earnings report'})
# 2026-03-25 16:22:58,578 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 16:24:38,862 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b25825334d0 state=finished raised ReadTimeout>]
# 2026-03-25 16:24:38,865 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b2582fca690 state=finished raised ReadTimeout>]
# 2026-03-25 16:24:38,923 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b25a0e102f0 state=finished raised ReadTimeout>]
# 2026-03-25 16:24:38,987 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b25a0e02de0 state=finished raised ReadTimeout>]
# 2026-03-25 16:24:39,016 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b2582eadaf0 state=finished raised ReadTimeout>]
# 2026-03-25 16:24:39,023 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-25 16:24:39,503 INFO google_adk.google.adk.models.gemini_context_cache_manager: Cache created successfully: cachedContents/ei8wfzv5zc9zwf1ie6dit8skfgw82eycn2cokkqi
# 2026-03-25 16:24:39,505 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-25 16:24:39,506 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 16:24:41,518 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-25 16:24:41,520 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'BMO Q3 2013 investor relations earnings release'})
# 2026-03-25 16:24:41,627 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 16:26:21,790 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b258253bef0 state=finished raised ReadTimeout>]
# 2026-03-25 16:26:21,813 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b25a277df10 state=finished raised ReadTimeout>]
# 2026-03-25 16:26:21,814 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b25a2722d80 state=finished raised ReadTimeout>]
# 2026-03-25 16:26:21,820 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-25 16:26:21,939 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-25 16:26:21,940 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 16:26:23,674 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-25 16:26:23,676 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'BMO investor relations quarterly reports 2013'})
# 2026-03-25 16:26:23,783 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 16:28:03,801 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b2582e985f0 state=finished raised ReadTimeout>]
# 2026-03-25 16:28:03,822 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b2582e9bbc0 state=finished raised ReadTimeout>]
# 2026-03-25 16:28:03,859 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b2582eadeb0 state=finished raised ReadTimeout>]
# 2026-03-25 16:28:03,861 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b25825a81a0 state=finished raised ReadTimeout>]
# 2026-03-25 16:28:03,869 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b25825793d0 state=finished raised ReadTimeout>]
# 2026-03-25 16:28:03,900 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b2582e6a780 state=finished raised ReadTimeout>]
# 2026-03-25 16:28:03,907 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-25 16:28:04,025 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-25 16:28:04,026 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 16:28:05,545 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-25 16:28:05,548 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'BMO financial reports archive investor relations'})
# 2026-03-25 16:28:05,662 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 16:29:43,108 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b25825daba0 state=finished raised ReadTimeout>]
# 2026-03-25 16:29:43,289 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b25825758b0 state=finished raised ReadTimeout>]
# 2026-03-25 16:29:43,304 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b25a27fb260 state=finished raised ReadTimeout>]
# 2026-03-25 16:29:43,331 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b2582e9ba40 state=finished raised ReadTimeout>]
# 2026-03-25 16:29:43,360 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b2582575d00 state=finished raised ReadTimeout>]
# 2026-03-25 16:29:43,369 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-25 16:29:43,489 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-25 16:29:43,490 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 16:29:45,416 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-25 16:29:45,418 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'BMO 6-K filing 2013 Q2 Q3 site:sec.gov'})
# 2026-03-25 16:29:45,527 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 16:31:24,375 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b25825774a0 state=finished raised ReadTimeout>]
# 2026-03-25 16:31:24,382 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b258257a510 state=finished raised ReadTimeout>]
# 2026-03-25 16:31:24,393 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-25 16:31:24,512 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-25 16:31:24,513 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 16:31:26,294 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-25 16:31:26,297 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'BMO Investor Relations historical financial reports'})
# 2026-03-25 16:31:26,410 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 16:33:04,489 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b2582574320 state=finished raised ReadTimeout>]
# 2026-03-25 16:33:04,491 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b2582575550 state=finished raised ReadTimeout>]
# 2026-03-25 16:33:04,577 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b25825f67b0 state=finished raised ReadTimeout>]
# 2026-03-25 16:33:04,603 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b25825dba40 state=finished raised ReadTimeout>]
# 2026-03-25 16:33:04,605 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b25825d8b90 state=finished raised ReadTimeout>]
# 2026-03-25 16:33:04,631 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b25825daae0 state=finished raised ReadTimeout>]
# ...
# 2026-03-25 17:50:50,224 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-25 17:50:50,226 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 17:50:52,754 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-25 17:50:52,758 INFO aieng.agent_evals.knowledge_qa.agent: Replanned with 4 new steps (keeping 6 completed)
# 2026-03-25 17:50:52,759 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'BMO Q3 2013 financial results'})
# 2026-03-25 17:50:52,886 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 17:52:32,939 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b2582f89970 state=finished raised ReadTimeout>]
# 2026-03-25 17:52:32,942 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b2582e58e90 state=finished raised ReadTimeout>]
# 2026-03-25 17:52:32,961 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b2580fae420 state=finished raised ReadTimeout>]
# 2026-03-25 17:52:32,966 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b25a27225d0 state=finished raised ReadTimeout>]
# 2026-03-25 17:52:33,005 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b25a0e024e0 state=finished raised ReadTimeout>]
# 2026-03-25 17:52:33,013 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-25 17:52:33,130 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-25 17:52:33,131 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 17:52:34,291 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-25 17:52:34,294 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: web_fetch({'query': 'BMO Q3 2013 revenue', 'url': 'https://www.investmentexecutive.com/news/industry-news/bmo-profits-rise-to-970m-in-q3/'})
# 2026-03-25 17:52:35,087 INFO aieng.agent_evals.tools.web: Fetched 16773 chars from https://www.investmentexecutive.com/news/industry-news/bmo-profits-rise-to-970m-in-q3/, extracting info...
# 2026-03-25 17:52:37,422 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: web_fetch completed
# 2026-03-25 17:52:37,551 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-25 17:52:37,553 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 17:52:39,714 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-25 17:52:39,717 INFO aieng.agent_evals.knowledge_qa.agent: Replanned with 4 new steps (keeping 8 completed)
# 2026-03-25 17:52:39,718 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'BMO Q3 2013 earnings press release'})
# 2026-03-25 17:52:39,827 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 17:54:19,085 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b2582ff4a40 state=finished raised ReadTimeout>]
# 2026-03-25 17:54:19,155 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b2582e99670 state=finished raised ReadTimeout>]
# 2026-03-25 17:54:19,163 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-25 17:54:19,285 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-25 17:54:19,287 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 17:54:22,020 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-25 17:54:22,024 INFO aieng.agent_evals.knowledge_qa.agent: Replanned with 4 new steps (keeping 9 completed)
# 2026-03-25 17:54:22,025 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'BMO total consolidated revenue Q3 2013'})
# 2026-03-25 17:54:22,146 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 17:55:59,821 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b25a27f9730 state=finished raised ReadTimeout>]
# 2026-03-25 17:55:59,823 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b25a0e11250 state=finished raised ReadTimeout>]
# 2026-03-25 17:55:59,829 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7b25a27a7ec0 state=finished raised ReadTimeout>]
# 2026-03-25 17:55:59,838 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-25 17:55:59,970 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-25 17:55:59,972 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 17:56:04,267 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-25 17:56:04,319 WARNING langfuse: Propagated attribute 'experiment_item_metadata' value is over 200 characters (242 chars). Dropping value.
# 2026-03-25 17:56:14,994 WARNING langfuse: Propagated attribute 'experiment_item_metadata' value is over 200 characters (248 chars). Dropping value.
# 2026-03-25 17:56:15,181 INFO aieng.agent_evals.knowledge_qa.agent: Answering question: Who left Canadian Imperial Bank of Commerce for National Bank in August 2013?...
# 2026-03-25 17:56:15,319 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-25 17:56:16,780 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-25 17:56:16,782 INFO aieng.agent_evals.knowledge_qa.agent: Extracted plan with 3 steps
# 2026-03-25 17:56:16,783 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'who left CIBC for National Bank August 2013'})
# 2026-03-25 17:56:16,920 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 17:56:20,919 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-25 17:56:21,492 INFO google_adk.google.adk.models.gemini_context_cache_manager: Cache created successfully: cachedContents/9ynlr37ykukihz9igq07lgwiw9zzjk6g08cehxu0
# 2026-03-25 17:56:21,495 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-25 17:56:21,496 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 17:56:23,207 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-25 17:56:23,210 INFO aieng.agent_evals.knowledge_qa.agent: Replanned with 3 new steps (keeping 0 completed)
# 2026-03-25 17:56:23,211 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'National Bank hires August 2013 CIBC'})
# 2026-03-25 17:56:23,422 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 17:56:33,016 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-25 17:56:33,135 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-25 17:56:33,137 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 17:56:34,921 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-25 17:56:34,923 INFO aieng.agent_evals.knowledge_qa.agent: Replanned with 3 new steps (keeping 1 completed)
# 2026-03-25 17:56:34,925 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'National Bank executive appointments August 2013'})
# 2026-03-25 17:56:35,043 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 17:56:40,097 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-25 17:56:40,223 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-25 17:56:40,225 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 17:56:42,311 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-25 17:56:42,359 WARNING langfuse: Propagated attribute 'experiment_item_metadata' value is over 200 characters (248 chars). Dropping value.
# 2026-03-25 17:56:49,102 WARNING langfuse: Propagated attribute 'experiment_item_metadata' value is over 200 characters (244 chars). Dropping value.
# 2026-03-25 17:56:49,275 INFO aieng.agent_evals.knowledge_qa.agent: Answering question: Who was set to become the first female chairman of a Canadian bank?...
# 2026-03-25 17:56:49,394 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-25 17:56:50,916 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-25 17:56:50,919 INFO aieng.agent_evals.knowledge_qa.agent: Extracted plan with 4 steps
# 2026-03-25 17:56:50,920 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'first female chairman Canadian bank'})
# 2026-03-25 17:56:51,041 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 17:56:55,506 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-25 17:56:56,012 INFO google_adk.google.adk.models.gemini_context_cache_manager: Cache created successfully: cachedContents/cp50o9uy8olt3se4c8zwev071rtoowgb67g0ppmx
# 2026-03-25 17:56:56,014 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-25 17:56:56,015 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 17:56:57,353 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-25 17:56:57,356 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: web_fetch({'url': 'https://www.scmp.com/business/banking-finance/article/1300781/rbc-picks-canadas-first-woman-bank-chairman', 'query': 'Who was set to become the first female chairman of a Canadian bank and which bank?'})
# 2026-03-25 17:56:57,491 INFO aieng.agent_evals.tools.web: Fetched 42482 chars from https://www.scmp.com/business/banking-finance/article/1300781/rbc-picks-canadas-first-woman-bank-chairman, extracting info...
# 2026-03-25 17:56:59,048 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: web_fetch completed
# 2026-03-25 17:56:59,160 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-25 17:56:59,161 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 17:57:00,697 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-25 17:57:00,742 WARNING langfuse: Propagated attribute 'experiment_item_metadata' value is over 200 characters (244 chars). Dropping value.
# 2026-03-25 17:57:08,193 WARNING langfuse: Propagated attribute 'experiment_item_metadata' value is over 200 characters (252 chars). Dropping value.
# 2026-03-25 17:57:08,356 INFO aieng.agent_evals.knowledge_qa.agent: Answering question: Who was named Scotiabank's new Chief Risk Officer in August 2013?...
# 2026-03-25 17:57:08,469 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-25 17:57:09,846 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-25 17:57:09,849 INFO aieng.agent_evals.knowledge_qa.agent: Extracted plan with 4 steps
# 2026-03-25 17:57:09,849 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'Scotiabank new Chief Risk Officer August 2013'})
# 2026-03-25 17:57:09,963 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 17:57:14,559 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-25 17:57:15,074 INFO google_adk.google.adk.models.gemini_context_cache_manager: Cache created successfully: cachedContents/zuujvme18e1nnhjatlp0ss5dp2nxuzge1gf2jxvy
# 2026-03-25 17:57:15,077 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-25 17:57:15,078 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 17:57:16,315 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-25 17:57:16,318 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: web_fetch({'url': 'https://www.newswire.ca/news-releases/scotiabank-announces-changes-to-senior-executive-team-512859821.html', 'query': "Who was named Scotiabank's new Chief Risk Officer in August 2013?"})
# 2026-03-25 17:57:16,482 INFO aieng.agent_evals.tools.web: Fetched 61422 chars from https://www.newswire.ca/news-releases/scotiabank-announces-changes-to-senior-executive-team-512859821.html, extracting info...
# 2026-03-25 17:57:18,213 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: web_fetch completed
# 2026-03-25 17:57:18,343 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-25 17:57:18,344 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-25 17:57:19,899 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-25 17:57:19,942 WARNING langfuse: Propagated attribute 'experiment_item_metadata' value is over 200 characters (252 chars). Dropping value.
# 2026-03-25 17:57:29,885 WARNING langfuse: Propagated attribute 'experiment_item_metadata' value is over 200 characters (246 chars). Dropping value.
# 2026-03-25 17:57:30,036 INFO aieng.agent_evals.knowledge_qa.agent: Answering question: How much in Aeroplan credit card loans was CIBC managing as TD negotiations continued?...
# 2026-03-25 17:57:30,149 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-25 17:57:32,373 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-25 17:57:32,375 INFO aieng.agent_evals.knowledge_qa.agent: Extracted plan with 5 steps
# 2026-03-25 17:57:32,376 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'TD Aeroplan negotiations history'})
# 2026-03-25 17:57:32,490 INFO google_genai.models: AFC is enabled with max remote calls: 10.

# %% [markdown]
# ## 4. Inspecting Results
#
# The `ExperimentResult` object gives programmatic access to every item-level score.
# Aggregate metrics are visible in the Langfuse experiment run summary in the UI.

# %%
rows = []
for item_result in experiment_result.item_results:
    item = item_result.item
    question = str(item.input)
    row = {
        "question": question[:55] + "..." if len(question) > 55 else question,
        "answer_type": (item.metadata or {}).get("answer_type", ""),
    }
    for evaluation in item_result.evaluations or []:
        row[evaluation.name] = evaluation.value
    rows.append(row)

df = pd.DataFrame(rows)
print(df.to_string(index=False))

# %%
# Mean of numeric metrics
numeric_cols = [c for c in ["F1", "Precision", "Recall"] if c in df.columns]
if numeric_cols:
    means_table = Table(title="Mean Scores")
    means_table.add_column("Metric", style="cyan")
    means_table.add_column("Mean", style="white")
    for col in numeric_cols:
        means_table.add_row(col, f"{df[col].mean():.3f}")
    console.print(means_table)

# Outcome distribution
if "Outcome" in df.columns:
    outcome_table = Table(title="Outcome Distribution")
    outcome_table.add_column("Outcome", style="cyan")
    outcome_table.add_column("Count", style="white", justify="right")
    outcome_table.add_column("Fraction", style="dim", justify="right")
    total = len(df)
    for outcome, count in df["Outcome"].value_counts().items():
        outcome_table.add_row(str(outcome), str(count), f"{count / total:.0%}")
    console.print(outcome_table)

# %% [markdown]
# ## 5. Iterating on the Agent
#
# The dataset in Langfuse is persistent — you don't need to re-upload it. To evaluate a modified
# agent, call `run_experiment` again with a new `name` argument. Langfuse will create a new
# experiment run and you can compare runs side-by-side in the UI.
#
# ### Levers to Explore
#
# - **System prompt** — edit `SYSTEM_INSTRUCTIONS_TEMPLATE` in `system_instructions.py` to change
#   the search strategy, verification rules, or final answer format
# - **Planning** — toggle `enable_planning=False` to skip PlanReAct and compare quality vs. speed
# - **Model** — change the Gemini model in `KnowledgeGroundedAgent` for different capability/cost trade-offs
# - **Dataset** — change the `category` filter in Section 1 or increase `samples` to cover more examples
#
# ### What to Look for in Langfuse
#
# - Items with **low F1** — did the agent fail to fetch the source? Stop early? Misread the question?
# - Items with **`correct_with_extraneous`** — is the agent over-generating? Can the prompt be tightened?
# - **Latency outliers** — which steps are slow? Is replanning happening unnecessarily?

# %% [markdown]
# ## Summary
#
# In this notebook you:
#
# 1. **Uploaded** a DeepSearchQA subset to Langfuse as a persistent, reusable dataset
# 2. **Understood** the LLM-as-judge grader: precision, recall, F1, and the four outcome categories
# 3. **Walked through** a single-sample evaluation end-to-end
# 4. **Ran** a full experiment with `run_experiment` and inspected item-level scores
# 5. **Learned** how to iterate: re-run with a new experiment name to compare configurations in Langfuse
#
# The evaluation pipeline is the foundation for systematic agent improvement — each iteration
# produces a new experiment run that you can compare to the baseline in the Langfuse UI.

# %%
console.print(Panel("[green]✓[/green] Notebook complete!", title="Done", border_style="green"))
if experiment_result.dataset_run_url:
    display(
        HTML(
            f'<p>View experiment results: <a href="{experiment_result.dataset_run_url}" target="_blank">{experiment_result.dataset_run_url}</a></p>'
        )
    )
