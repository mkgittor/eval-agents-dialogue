# %% [markdown]
# # 03: Evaluation
#
# In Notebook 02 we ran individual questions by hand. This notebook evaluates the agent
# systematically: we upload a dataset subset to Langfuse, run the agent on every item, and
# score each response with an LLM-as-judge grader using the official DeepSearchQA methodology.
#
# ## What You'll Learn
#
# 1. Uploading a DeepSearchQA subset to Langfuse as a persistent dataset
# 2. The LLM-as-judge grader: precision, recall, F1, and the four outcome categories
# 3. A single-sample evaluation walkthrough
# 4. Running the full experiment with `run_experiment`
# 5. Inspecting and interpreting item-level results
#
# ## Prerequisites
#
# Complete Notebooks 01 and 02. You'll need all credentials in `.env`:
# - `GOOGLE_API_KEY`
# - `LANGFUSE_PUBLIC_KEY` and `LANGFUSE_SECRET_KEY`
# - `OPENAI_API_KEY` (for the LLM grader)

# %%
import json
import os
import tempfile
from pathlib import Path
from typing import Any

import pandas as pd
from aieng.agent_evals.evaluation import run_experiment
from aieng.agent_evals.evaluation.graders.config import LLMRequestConfig
from aieng.agent_evals.knowledge_qa import KnowledgeGroundedAgent
from knowledge_qa_cibc.bloombergfinance_grader import (
    EvaluationOutcome,
    evaluate_bloomberg_groundtruth_async,
)
from aieng.agent_evals.knowledge_qa.notebook import display_response, run_with_display
from aieng.agent_evals.langfuse import upload_dataset_to_langfuse
from dotenv import load_dotenv
from IPython.display import HTML, display  # noqa: A004
from langfuse.experiment import Evaluation
from rich.console import Console
from rich.panel import Panel
from rich.table import Table
from knowledge_qa_cibc import BloombergFinancialNewsDataset


# Set working directory to the repository root
if Path("").absolute().name == "eval-agents":
    print(f"Working directory: {Path('').absolute()}")
else:
    os.chdir(Path("").absolute().parent)
    print(f"Working directory set to: {Path('').absolute()}")

load_dotenv(verbose=True)

console = Console(width=100)

DATASET_NAME = "Bloomberg-Financial"
# Out:
# Working directory: /home/coder/eval-agents

# %%
dataset = BloombergFinancialNewsDataset()
dataset.sample(20)
# Out:
# 2026-03-24 17:40:42,033 INFO knowledge_qa_cibc.data.bloombergfinance: Loading golden eval data from /home/coder/eval-agents/worklib-cibc-two/knowledge_qa_cibc/data/golden_eval.json...
# 2026-03-24 17:40:42,037 INFO knowledge_qa_cibc.data.bloombergfinance: Loaded 30 golden eval examples
# [BloombergNewsExample(input="What was Scotiabank's exposure to emerging market debt in Q3 2013?", expected_output='This information is not available in the Bloomberg articles from August 27-30, 2013.', metadata=GoldenEvalMetadata(example_id=24, category='unanswerable', answer_type='Single Answer', bank='Scotiabank', question_type='unanswerable', source_date='N/A', source_headline='N/A - not covered in dataset')),
#  BloombergNewsExample(input="Who was named Scotiabank's new Chief Risk Officer in August 2013?", expected_output='Hart, replacing Pitfield who retired', metadata=GoldenEvalMetadata(example_id=9, category='personnel', answer_type='Single Answer', bank='Scotiabank', question_type='single_article', source_date='2013-08-29', source_headline='Scotiabank Names Hart Chief Risk Officer as Pitfield Retires')),
#  BloombergNewsExample(input="What was Royal Bank of Canada's Q3 2013 net income?", expected_output='C$2.3 billion ($2.19 billion), or C$1.52 a share', metadata=GoldenEvalMetadata(example_id=1, category='earnings', answer_type='Single Answer', bank='RBC', question_type='single_article', source_date='2013-08-29', source_headline='RBC Tops Estimates as Third-Quarter Profit Rises 2.9%')),
#  BloombergNewsExample(input="What was Canada's second-quarter GDP growth rate in 2013 and how did it affect expectations for the banks?", expected_output="Canada's second-quarter growth slowed to a 1.7 percent pace. Despite this, analysts expected bank profits to rally as rising interest rates would make lending more profitable.", metadata=GoldenEvalMetadata(example_id=29, category='macro', answer_type='Single Answer', bank='all', question_type='multi_article', source_date='2013-08-30', source_headline="Canada's Second-Quarter Growth Slows to 1.7% Pace; Canada Banks' Profits Poised to Rally")),
#  BloombergNewsExample(input='What common theme drove record profits at both BMO and Scotiabank in Q3 2013?', expected_output='Both banks posted record results in Canadian consumer lending and wealth management', metadata=GoldenEvalMetadata(example_id=16, category='comparative', answer_type='Single Answer', bank='all', question_type='multi_article', source_date='2013-08-27', source_headline='BMO, Scotiabank Beat Estimates on Increased Lending')),
#  BloombergNewsExample(input="What was the Bank of Canada's policy interest rate in August 2013 and was it expected to change?", expected_output='This specific information is not available in the Bloomberg articles from August 27-30, 2013. The articles discuss rising bond yields and interest rate expectations but do not state the policy rate.', metadata=GoldenEvalMetadata(example_id=30, category='unanswerable', answer_type='Single Answer', bank='all', question_type='unanswerable', source_date='N/A', source_headline='N/A - policy rate not explicitly stated in dataset')),
#  BloombergNewsExample(input='Which Canadian Big Five bank reported the largest percentage profit increase in Q3 2013 and which reported a decline?', expected_output='Bank of Montreal reported the largest increase at 17 percent. Toronto-Dominion was the only bank to report a decline, with profit falling 10 percent due to weather insurance costs.', metadata=GoldenEvalMetadata(example_id=15, category='comparative', answer_type='Single Answer', bank='all', question_type='multi_article', source_date='2013-08-27 to 2013-08-29', source_headline='Multiple earnings articles')),
#  BloombergNewsExample(input="What drove RBC's profit growth in Q3 2013?", expected_output='A 51 percent increase in profit from its wealth-management unit, as fund sales and improving stock markets lifted fee-based client assets, plus contributions from RBC Investor Services after buying out partner Banque Internationale a Luxembourg SA in July 2012', metadata=GoldenEvalMetadata(example_id=7, category='causal', answer_type='Single Answer', bank='RBC', question_type='single_article', source_date='2013-08-29', source_headline='RBC Tops Estimates as Third-Quarter Profit Rises 2.9%')),
#  BloombergNewsExample(input="What was TD Bank's wealth-management and insurance unit profit in Q3 2013?", expected_output='C$7 million, down from C$360 million a year earlier', metadata=GoldenEvalMetadata(example_id=6, category='earnings', answer_type='Single Answer', bank='TD', question_type='single_article', source_date='2013-08-29', source_headline='Toronto-Dominion Profit Falls 10% on Weather Insurance Costs')),
#  BloombergNewsExample(input='Compare the Q3 2013 earnings per share of all Big Five Canadian banks. Which had the highest and lowest EPS?', expected_output='CIBC had the highest adjusted EPS at C$2.29, followed by BMO at C$1.68, TD at C$1.58, RBC at C$1.52, and Scotiabank at C$1.37. CIBC had the highest and Scotiabank had the lowest.', metadata=GoldenEvalMetadata(example_id=13, category='comparative', answer_type='Single Answer', bank='all', question_type='multi_article', source_date='2013-08-27 to 2013-08-29', source_headline='Multiple earnings articles across all five banks')),
#  BloombergNewsExample(input='Did any of the Big Five Canadian banks announce layoffs in August 2013?', expected_output='No layoff announcements from the Big Five banks are reported in the Bloomberg articles from August 27-30, 2013.', metadata=GoldenEvalMetadata(example_id=26, category='unanswerable', answer_type='Single Answer', bank='all', question_type='unanswerable', source_date='N/A', source_headline='N/A - not covered in dataset')),
#  BloombergNewsExample(input='By how much did RBC and Scotiabank each raise their dividends in Q3 2013?', expected_output='RBC raised its dividend 6.3 percent to 67 cents a share. Scotiabank raised its dividend 3.3 percent to 62 cents a share.', metadata=GoldenEvalMetadata(example_id=28, category='comparative', answer_type='Single Answer', bank='all', question_type='multi_article', source_date='2013-08-27 to 2013-08-29', source_headline='RBC Tops Estimates; Scotiabank Profit Beats Estimates')),
#  BloombergNewsExample(input="What was CIBC's credit rating from Moody's in August 2013?", expected_output='This information is not available in the Bloomberg articles from August 27-30, 2013.', metadata=GoldenEvalMetadata(example_id=22, category='unanswerable', answer_type='Single Answer', bank='CIBC', question_type='unanswerable', source_date='N/A', source_headline='N/A - not covered in dataset')),
#  BloombergNewsExample(input='Who was set to become the first female chairman of a Canadian bank?', expected_output="RBC's Taylor", metadata=GoldenEvalMetadata(example_id=10, category='personnel', answer_type='Single Answer', bank='RBC', question_type='single_article', source_date='2013-08-30', source_headline="RBC's Taylor to Be First Female Chairman of Canadian Bank")),
#  BloombergNewsExample(input="What was BMO's Q3 2013 revenue?", expected_output='C$4.05 billion, up 4.4 percent from a year earlier', metadata=GoldenEvalMetadata(example_id=12, category='earnings', answer_type='Single Answer', bank='BMO', question_type='single_article', source_date='2013-08-27', source_headline='Bank of Montreal Profit Tops Estimates on Consumer Loans')),
#  BloombergNewsExample(input="What was Royal Bank of Canada's Q4 2013 net income?", expected_output='This information is not available in the Bloomberg articles from late August 2013. Q4 2013 results had not been reported yet.', metadata=GoldenEvalMetadata(example_id=21, category='unanswerable', answer_type='Single Answer', bank='RBC', question_type='unanswerable', source_date='N/A', source_headline='N/A - Q4 results not yet reported')),
#  BloombergNewsExample(input="Why did Toronto-Dominion Bank's profit fall in Q3 2013?", expected_output='Insurance losses from severe weather claims, including flooding in southern Alberta in June and a record deluge in Toronto that submerged parts of the city on June 8', metadata=GoldenEvalMetadata(example_id=2, category='causal', answer_type='Single Answer', bank='TD', question_type='single_article', source_date='2013-08-29', source_headline='Toronto-Dominion Profit Falls 10% on Weather Insurance Costs')),
#  BloombergNewsExample(input="By what percentage did CIBC's Q3 2013 profit rise and what unit drove the growth?", expected_output='5.8 percent, driven by its wealth-management unit', metadata=GoldenEvalMetadata(example_id=5, category='earnings', answer_type='Single Answer', bank='CIBC', question_type='single_article', source_date='2013-08-29', source_headline='Canadian Imperial Profit Rises 5.8% on Wealth Management Gains')),
#  BloombergNewsExample(input='Who left Canadian Imperial Bank of Commerce for National Bank in August 2013?', expected_output='Hashimoto and Bhutani', metadata=GoldenEvalMetadata(example_id=11, category='personnel', answer_type='Set Answer', bank='CIBC', question_type='single_article', source_date='2013-08-30', source_headline='Hashimoto and Bhutani Leave Canadian Imperial for National Bank')),
#  BloombergNewsExample(input="Which of Canada's Big Five banks raised their dividends in Q3 2013 and by how much?", expected_output='Royal Bank of Canada raised its dividend 6.3 percent to 67 cents, Toronto-Dominion raised 4.9 percent to 85 cents, and Bank of Nova Scotia raised 3.3 percent to 62 cents', metadata=GoldenEvalMetadata(example_id=14, category='comparative', answer_type='Set Answer', bank='all', question_type='multi_article', source_date='2013-08-27 to 2013-08-29', source_headline='Multiple earnings articles'))]

# %% [markdown]
# ## 1. Uploading the Dataset to Langfuse
#
# Langfuse stores our evaluation dataset so we can run multiple experiments against the same items
# and compare results over time. Each dataset item has three fields:
#
# - **`input`**: the question (sent to the agent)
# - **`expected_output`**: the ground truth answer (given to the grader, never shown to the agent)
# - **`metadata`**: `category`, `answer_type`, `example_id`
#
# Items are deduplicated by a hash of their content, so running this cell again is safe.

# %%
# dataset = BloombergFinancialNewsDataset()
# # examples = dataset.get_by_category("Finance & Economics")[:1]
# examples = dataset.sample(20)
# console.print(f"Uploading [cyan]{len(examples)}[/cyan] examples to dataset '{DATASET_NAME}'...")

# # Write examples to a temporary JSONL file for the upload utility
# with tempfile.NamedTemporaryFile(mode="w", suffix=".jsonl", delete=False, encoding="utf-8") as f:
#     for ex in examples:
#         record = {
#             "input": ex.problem,
#             "expected_output": ex.answer,
#             "metadata": {
#                 "example_id": ex.example_id,
#                 "category": ex.problem_category,
#                 "answer_type": ex.answer_type,
#             },
#         }
#         f.write(json.dumps(record, ensure_ascii=False) + "\n")
#     temp_path = f.name

temp_path = "./worklib-cibc-two/knowledge_qa_cibc/data/golden_eval.json"
await upload_dataset_to_langfuse(dataset_path=temp_path, dataset_name=DATASET_NAME)
# os.unlink(temp_path)

# console.print(f"[green]✓[/green] Dataset '{DATASET_NAME}' ready in Langfuse")
# Out:
# 2026-03-24 15:34:34,627 INFO aieng.agent_evals.langfuse: Loading dataset from 'worklib-cibc-two/knowledge_qa_cibc/data/golden_eval.json'
# Uploading Langfuse dataset 'Bloomberg-Financial' ━━━━━━━━━ 30/30 0:00:00 0:00:0200:0200:02
# 2026-03-24 15:34:37,319 INFO aieng.agent_evals.langfuse: Uploaded 30 items to dataset 'Bloomberg-Financial'

# %% [markdown]
# ## 2. The Bloomberg Grader
#
# The grader is an LLM-as-judge that evaluates answers using the official Bloomberg methodology
# from Appendix A of the paper. It handles both answer types:
#
# - **Single Answer**: checks whether the response contains the one expected value
# - **Set Answer**: checks which items from the ground truth set appear in the response,
#   and flags any extra items the agent included
#
# ### Metrics
#
# Let **S** = predicted items, **G** = ground truth items:
#
# | Metric | Formula | Meaning |
# |--------|---------|---------|
# | **Precision** | \|S∩G\| / \|S\| | Of what the agent said, how much was correct |
# | **Recall** | \|S∩G\| / \|G\| | Of the ground truth, how much did the agent find |
# | **F1** | 2·P·R / (P+R) | Harmonic mean of precision and recall |
#
# ### Outcome Classification
#
# | Outcome | Condition | Interpretation |
# |---------|-----------|----------------|
# | `fully_correct` | S = G | Perfect answer |
# | `correct_with_extraneous` | G ⊆ S | All correct, but extra items included |
# | `partially_correct` | S∩G ≠ ∅ | Some correct items found |
# | `fully_incorrect` | S∩G = ∅ | No correct items |

# %% [markdown]
# ### 2.1 Single-Sample Walkthrough
#
# Before running at scale, let's walk through one example end-to-end: run the agent,
# then grade its response with the LLM judge.

# %%
# Pick one example for the walkthrough
example = dataset[0]

console.print(
    Panel(
        f"[bold]ID:[/bold] {example.metadata.example_id}\n"
        f"[bold]Category:[/bold] {example.metadata.category}\n"
        f"[bold]Answer Type:[/bold] {example.metadata.answer_type}\n"
        f"[bold]Bank:[/bold] {example.metadata.bank}\n\n"
        f"[bold cyan]Question:[/bold cyan]\n{example.input}\n\n"
        f"[bold yellow]Ground Truth:[/bold yellow]\n{example.expected_output}",
        title="Golden Evaluation Example",
        border_style="blue",
    )
)
# Out:
# ╭─────────────────────────────────── Golden Evaluation Example ────────────────────────────────────╮
# │ ID: 1                                                                                            │
# │ Category: earnings                                                                               │
# │ Answer Type: Single Answer                                                                       │
# │ Bank: RBC                                                                                        │
# │                                                                                                  │
# │ Question:                                                                                        │
# │ What was Royal Bank of Canada's Q3 2013 net income?                                              │
# │                                                                                                  │
# │ Ground Truth:                                                                                    │
# │ C$2.3 billion ($2.19 billion), or C$1.52 a share                                                 │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
eval_agent = KnowledgeGroundedAgent(enable_planning=True)
eval_response = await run_with_display(eval_agent, example.input)

display_response(
    console,
    eval_response.text,
    title="Agent Answer",
    subtitle=f"Duration: {eval_response.total_duration_ms / 1000:.1f}s  |  Tools: {len(eval_response.tool_calls)}",
)
# Out:
# <div style="max-width: 800px;">
# <div style="padding: 10px; background: #cfe2ff; border-radius: 8px; margin-bottom: 8px;"><b>Question:</b> What was Royal Bank of Canada's Q3 2013 net income?</div>
# <div style="font-family: monospace; padding: 10px; background: #e9ecef; border-radius: 8px; margin-top: 8px;">
# <div style="font-weight: bold; margin-bottom: 8px;">🔧 Tool Calls (2)</div>
# <div style="margin: 2px 0;"><span style="color: #28a745;">✓</span> 🔍 <b>google_search</b> <span style="color: #6c757d;">{'query': 'Royal Bank of Canada Q3 2013 net income'}</span></div>
# <div style="margin: 2px 0;"><span style="color: #28a745;">✓</span> 🌐 <b>web_fetch</b> <span style="color: #6c757d;">{'url': 'https://www.rbc.com/investor-relations/_assets-c...</span></div>
# </div>
# </div><div style="margin-top: 12px; padding: 10px; background: #d4edda; border-radius: 8px;">✓ Complete in 11.8s | 2 tool calls | 5 sources</div>
# ╭────────────────────────────────────────── Agent Answer ──────────────────────────────────────────╮
# │ Royal Bank of Canada's net income for Q3 2013 was $2,304 million.                                │
# ╰────────────────────────────────── Duration: 11.8s  |  Tools: 2 ──────────────────────────────────╯
# ╭──────────────────────────────────────────── Sources ─────────────────────────────────────────────╮
# │   https://www.rbc.com/investor-relations/_assets-custom/pdf/q32013release.pdf                    │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────── Reasoning ────────────────────────────────────────────╮
# │ The fetched document states: "Royal Bank of Canada... today reported record net income of $2,304 │
# │ million for the quarter ended July 31, 2013...".                                                 │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
console.print("[dim]Grading with LLM judge against ground truth...[/dim]\n")

result = await evaluate_bloomberg_groundtruth_async(
    question=example.input,
    answer=eval_response.text,
    ground_truth=example.expected_output,
    answer_type=example.metadata.answer_type,
    model_config=LLMRequestConfig(temperature=0.0),
)

outcome_color = {
    EvaluationOutcome.FULLY_CORRECT: "green",
    EvaluationOutcome.CORRECT_WITH_EXTRANEOUS: "yellow",
    EvaluationOutcome.PARTIALLY_CORRECT: "orange1",
    EvaluationOutcome.FULLY_INCORRECT: "red",
}.get(result.outcome, "white")

metrics_table = Table(title="Grader Results")
metrics_table.add_column("Metric", style="cyan")
metrics_table.add_column("Value", style="white")
metrics_table.add_row("Outcome", f"[{outcome_color}]{result.outcome.value}[/{outcome_color}]")
metrics_table.add_row("Precision", f"{result.precision:.3f}")
metrics_table.add_row("Recall", f"{result.recall:.3f}")
metrics_table.add_row("F1", f"[bold]{result.f1_score:.3f}[/bold]")
console.print(metrics_table)

if result.explanation:
    console.print(Panel(result.explanation, title="Grader Explanation", border_style="magenta"))

# Show per-item correctness for Set Answer questions
if result.correctness_details:
    details_table = Table(title="Correctness Details")
    details_table.add_column("Expected Item", style="white")
    details_table.add_column("Found", style="cyan", justify="center")
    for item, found in result.correctness_details.items():
        icon = "[green]\u2713[/green]" if found else "[red]\u2717[/red]"
        label = item[:60] + "..." if len(item) > 60 else item
        details_table.add_row(label, icon)
    console.print(details_table)
# Out:
# Grading with LLM judge against ground truth...
#          Grader Results
# ┏━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Metric    ┃ Value             ┃
# ┡━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ Outcome   │ partially_correct │
# │ Precision │ 1.000             │
# │ Recall    │ 0.333             │
# │ F1        │ 0.500             │
# └───────────┴───────────────────┘
# ╭─────────────────────────────────────── Grader Explanation ───────────────────────────────────────╮
# │ The AI correctly identifies the net income as '$2,304 million', which is an equivalent and more  │
# │ precise representation of the 'C$2.3 billion' from the correct answer. However, the AI's         │
# │ response omits the USD equivalent ('$2.19 billion') and the earnings per share ('C$1.52 a        │
# │ share') which were also part of the ground truth.                                                │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
#    Correctness Details
# ┏━━━━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Expected Item  ┃ Found ┃
# ┡━━━━━━━━━━━━━━━━╇━━━━━━━┩
# │ C$2.3 billion  │   ✓   │
# │ $2.19 billion  │   ✗   │
# │ C$1.52 a share │   ✗   │
# └────────────────┴───────┘

# %% [markdown]
# ## 3. Running the Evaluation Experiment
#
# `run_experiment` runs the agent against every item in the Langfuse dataset, scores each
# response, and records results in Langfuse. Each call creates a new named experiment run
# that you can compare to previous runs in the UI.
#
# The experiment takes two functions:
#
# - **`agent_task`** — receives a dataset item, runs the agent, returns the answer string
# - **`deepsearchqa_evaluator`** — receives question, answer, and ground truth; returns grader scores
#
# > **Note:** This makes one agent call and one grader call per item. With 10 items and
# > `max_concurrency=1`, expect 20–40 minutes depending on model latency.

# %%
async def agent_task(*, item: Any, **kwargs: Any) -> str:
    """Run the Knowledge Agent on a Langfuse dataset item."""
    agent = KnowledgeGroundedAgent(enable_planning=True)
    response = await agent.answer_async(item.input)
    return response.text


async def bloomberg_groundtruth_evaluator(
    *,
    input: str,  # noqa: A002
    output: str,
    expected_output: str,
    metadata: dict[str, Any] | None = None,
    **kwargs: Any,
) -> list[Evaluation]:
    """LLM-as-judge grader comparing agent answer to ground truth."""
    answer_type = (metadata or {}).get("answer_type", "Single Answer")
    result = await evaluate_bloomberg_groundtruth_async(
        question=input,
        answer=output,
        ground_truth=expected_output,
        answer_type=answer_type,
        model_config=LLMRequestConfig(temperature=0.0),
    )
    return result.to_evaluations()

# %%
experiment_result = run_experiment(
    DATASET_NAME,
    name="knowledge-agent-baseline",
    task=agent_task,
    evaluators=[bloomberg_groundtruth_evaluator],
    description="Baseline Knowledge Agent on Finance & Economics questions.",
    max_concurrency=1,
)

console.print("[green]✓[/green] Experiment complete")
if experiment_result.dataset_run_url:
    display(
        HTML(
            f'<p>View experiment: <a href="{experiment_result.dataset_run_url}" target="_blank">{experiment_result.dataset_run_url}</a></p>'
        )
    )
# Out:
# 2026-03-24 17:41:51,737 WARNING langfuse: Propagated attribute 'experiment_item_metadata' value is over 200 characters (231 chars). Dropping value.
# 2026-03-24 17:41:51,912 INFO aieng.agent_evals.knowledge_qa.agent: Answering question: What was the Bank of Canada's policy interest rate in August 2013 and was it expected to change?...
# 2026-03-24 17:41:52,033 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 17:41:54,581 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 17:41:54,585 INFO aieng.agent_evals.knowledge_qa.agent: Extracted plan with 4 steps
# 2026-03-24 17:41:54,586 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'Bank of Canada policy interest rate August 2013'})
# 2026-03-24 17:41:54,706 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 17:41:58,098 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-24 17:41:58,591 INFO google_adk.google.adk.models.gemini_context_cache_manager: Cache created successfully: cachedContents/f70qcubol54emwxqgfg6vnznw8h8w4lmzkhvg0m8
# 2026-03-24 17:41:58,594 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 17:41:58,597 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 17:41:59,798 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 17:41:59,801 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: web_fetch({'url': 'https://www.cbc.ca/news/business/bank-of-canada-holds-rate-steady-as-carney-exits-1.1335397', 'query': 'Bank of Canada policy interest rate in August 2013 and expectations for change'})
# 2026-03-24 17:45:03,155 ERROR aieng.agent_evals.tools.web: Failed to fetch https://www.cbc.ca/news/business/bank-of-canada-holds-rate-steady-as-carney-exits-1.1335397 after 3 retries:
# 2026-03-24 17:45:03,160 WARNING aieng.agent_evals.knowledge_qa.agent: Tool error: web_fetch failed - Failed after 3 retries:
# 2026-03-24 17:45:03,275 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 17:45:03,277 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 17:45:04,492 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 17:45:04,495 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: web_fetch({'query': 'Bank of Canada policy interest rate in August 2013 and expectations for change', 'url': 'https://www.bankofcanada.ca/2013/09/fad-press-release-2013-09-04/'})
# 2026-03-24 17:45:05,062 INFO aieng.agent_evals.tools.web: Fetched 55152 chars from https://www.bankofcanada.ca/2013/09/fad-press-release-2013-09-04/, extracting info...
# 2026-03-24 17:45:07,941 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: web_fetch completed
# 2026-03-24 17:45:08,057 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 17:45:08,059 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 17:45:09,971 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 17:45:10,012 WARNING langfuse: Propagated attribute 'experiment_item_metadata' value is over 200 characters (231 chars). Dropping value.
# 2026-03-24 17:45:19,835 WARNING langfuse: Propagated attribute 'experiment_item_metadata' value is over 200 characters (270 chars). Dropping value.
# 2026-03-24 17:45:20,004 INFO aieng.agent_evals.knowledge_qa.agent: Answering question: What was Canada's second-quarter GDP growth rate in 2013 and how did it affect expectations for the ...
# 2026-03-24 17:45:20,118 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 17:45:24,488 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 17:45:24,492 INFO aieng.agent_evals.knowledge_qa.agent: Extracted plan with 4 steps
# 2026-03-24 17:45:24,493 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'Canada Q2 2013 GDP growth rate'})
# 2026-03-24 17:45:24,605 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 17:45:28,162 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-24 17:45:28,633 INFO google_adk.google.adk.models.gemini_context_cache_manager: Cache created successfully: cachedContents/6rrf5kkvr7qq82d902c8c9zvb6r11wlkvameptt0
# 2026-03-24 17:45:28,636 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 17:45:28,637 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 17:45:29,546 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 17:45:29,548 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'Canada Q2 2013 GDP growth rate effect on bank expectations'})
# 2026-03-24 17:45:29,657 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 17:45:43,076 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-24 17:45:43,192 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 17:45:43,193 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 17:45:45,712 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 17:45:45,755 WARNING langfuse: Propagated attribute 'experiment_item_metadata' value is over 200 characters (270 chars). Dropping value.
# 2026-03-24 17:45:59,260 WARNING langfuse: Propagated attribute 'experiment_item_metadata' value is over 200 characters (255 chars). Dropping value.
# 2026-03-24 17:45:59,419 INFO aieng.agent_evals.knowledge_qa.agent: Answering question: By how much did RBC and Scotiabank each raise their dividends in Q3 2013?...
# 2026-03-24 17:45:59,530 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 17:46:03,078 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 17:46:03,080 INFO aieng.agent_evals.knowledge_qa.agent: Extracted plan with 4 steps
# 2026-03-24 17:46:03,081 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'RBC dividend increase Q3 2013'})
# 2026-03-24 17:46:03,190 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 17:46:08,286 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-24 17:46:08,807 INFO google_adk.google.adk.models.gemini_context_cache_manager: Cache created successfully: cachedContents/jhd0dd3acbjbef310jp0rywpwyxi1ef0m41q8i9w
# 2026-03-24 17:46:08,810 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 17:46:08,811 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 17:46:09,949 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 17:46:09,951 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: web_fetch({'url': 'https://www.rbc.com/newsroom/news/article.html?article=123529', 'query': 'RBC dividend increase Q3 2013'})
# 2026-03-24 17:46:10,198 INFO aieng.agent_evals.tools.web: Fetched 4247 chars from https://www.rbc.com/newsroom/news/article.html?article=123529, extracting info...
# 2026-03-24 17:46:11,541 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: web_fetch completed
# 2026-03-24 17:46:11,659 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 17:46:11,660 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 17:46:12,632 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 17:46:12,635 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: web_fetch({'query': 'RBC dividend increase amount in Q3 2013', 'url': 'https://www.rbc.com/investor-relations/_assets-custom/pdf/q32013release.pdf'})
# 2026-03-24 17:46:13,135 INFO aieng.agent_evals.tools.web: Extracted 20550 chars from PDF (4 pages), extracting info...
# 2026-03-24 17:46:14,763 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: web_fetch completed
# 2026-03-24 17:46:14,874 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 17:46:14,875 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 17:46:15,824 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 17:46:15,827 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'Scotiabank dividend increase Q3 2013'})
# 2026-03-24 17:46:15,935 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 17:46:20,075 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-24 17:46:20,190 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 17:46:20,192 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 17:46:21,387 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 17:46:21,389 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: web_fetch({'query': 'Scotiabank dividend increase amount in Q3 2013', 'url': 'https://www.dividendmax.com/canada/toronto-stock-exchange/banks/bank-of-nova-scotia/dividends'})
# 2026-03-24 17:46:22,262 INFO aieng.agent_evals.tools.web: Fetched 13819 chars from https://www.dividendmax.com/canada/toronto-stock-exchange/banks/bank-of-nova-scotia/dividends, extracting info...
# 2026-03-24 17:46:25,894 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: web_fetch completed
# 2026-03-24 17:46:26,009 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 17:46:26,010 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 17:46:31,448 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 17:46:31,451 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'RBC dividend increase Q3 2013'})
# 2026-03-24 17:46:31,566 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 17:46:35,299 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-24 17:46:35,417 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 17:46:35,419 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 17:46:36,670 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 17:46:36,673 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: web_fetch({'query': 'RBC dividend increase amount in Q3 2013', 'url': 'https://www.rbc.com/investor-relations/_assets-custom/pdf/q32013release.pdf'})
# 2026-03-24 17:46:36,938 INFO aieng.agent_evals.tools.web: Extracted 20550 chars from PDF (4 pages), extracting info...
# 2026-03-24 17:46:38,588 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: web_fetch completed
# 2026-03-24 17:46:38,700 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 17:46:38,701 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 17:46:40,155 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 17:46:40,157 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'Scotiabank dividend increase Q3 2013'})
# 2026-03-24 17:46:40,269 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 17:46:45,920 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-24 17:46:46,038 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 17:46:46,039 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 17:46:47,379 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 17:46:47,382 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: web_fetch({'query': 'Scotiabank dividend increase amount in Q3 2013', 'url': 'https://www.dividendmax.com/canada/toronto-stock-exchange/banks/bank-of-nova-scotia/dividends'})
# 2026-03-24 17:46:48,970 INFO aieng.agent_evals.tools.web: Fetched 13819 chars from https://www.dividendmax.com/canada/toronto-stock-exchange/banks/bank-of-nova-scotia/dividends, extracting info...
# 2026-03-24 17:46:51,820 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: web_fetch completed
# 2026-03-24 17:46:51,937 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 17:46:51,939 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 17:46:55,296 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 17:46:55,340 WARNING langfuse: Propagated attribute 'experiment_item_metadata' value is over 200 characters (255 chars). Dropping value.
# 2026-03-24 17:47:06,974 WARNING langfuse: Propagated attribute 'experiment_item_metadata' value is over 200 characters (214 chars). Dropping value.
# 2026-03-24 17:47:07,135 INFO aieng.agent_evals.knowledge_qa.agent: Answering question: What was the share price performance of Big Five Canadian bank stocks relative to the S&P/TSX Financ...
# 2026-03-24 17:47:07,251 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 17:47:41,936 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 17:47:41,939 INFO aieng.agent_evals.knowledge_qa.agent: Extracted plan with 4 steps
# 2026-03-24 17:47:41,940 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'Big Five Canadian bank stocks'})
# 2026-03-24 17:47:42,054 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 17:49:22,612 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7bf850469760 state=finished raised ReadTimeout>]
# 2026-03-24 17:49:22,621 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-24 17:49:23,214 INFO google_adk.google.adk.models.gemini_context_cache_manager: Cache created successfully: cachedContents/dg7oruk8cq78od4x9mlxymct0947qp8iyrdi8vqw
# 2026-03-24 17:49:23,217 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 17:49:23,218 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 17:49:24,228 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 17:49:24,231 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'S&P/TSX Financials Index'})
# 2026-03-24 17:49:24,345 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 17:49:31,710 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-24 17:49:31,823 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 17:49:31,824 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 17:49:32,807 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 17:49:32,810 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'S&P/TSX Financials Index performance August 27-30 2013'})
# 2026-03-24 17:49:32,922 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 17:49:46,296 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-24 17:49:46,409 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 17:49:46,410 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 17:49:47,565 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 17:49:47,568 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: web_fetch({'url': 'https://ca.investing.com/indices/s-p-tsx-canadian-financials-historical-data', 'query': "S&P/TSX Canadian Financials Index historical data for August 27, 2013 to August 30, 2013, specifically the 'Price' column, to calculate the percentage change during this period."})
# 2026-03-24 17:49:48,107 INFO aieng.agent_evals.tools.web: Fetched 180724 chars from https://ca.investing.com/indices/s-p-tsx-canadian-financials-historical-data, extracting info...
# 2026-03-24 17:49:50,479 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: web_fetch completed
# 2026-03-24 17:49:50,598 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 17:49:50,599 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 17:49:51,569 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 17:49:51,571 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'historical stock data Big Five Canadian banks S&P/TSX Financials Index August 27-30 2013'})
# 2026-03-24 17:49:51,683 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 17:52:09,734 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7bf850338aa0 state=finished raised ReadTimeout>]
# 2026-03-24 17:52:09,742 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-24 17:52:09,859 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 17:52:09,860 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 17:52:12,605 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 17:52:12,607 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: web_fetch({'query': 'Royal Bank of Canada (RY.TO) closing price on August 27, 2013 and August 30, 2013', 'url': 'https://stockanalysis.com/quote/tsx/RY/history/'})
# 2026-03-24 17:52:12,805 INFO aieng.agent_evals.tools.web: Fetched 1329 chars from https://stockanalysis.com/quote/tsx/RY/history/, extracting info...
# 2026-03-24 17:52:14,033 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: web_fetch completed
# 2026-03-24 17:52:14,150 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 17:52:14,152 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 17:52:15,868 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 17:52:15,871 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: web_fetch({'query': 'Royal Bank of Canada (RY.TO) closing stock price on August 27, 2013 and August 30, 2013', 'url': 'https://www.macrotrends.net/stocks/charts/RY/royal-bank-of-canada/stock-price-history'})
# 2026-03-24 17:52:19,128 ERROR aieng.agent_evals.tools.web: HTTP error fetching https://www.macrotrends.net/stocks/charts/RY/royal-bank-of-canada/stock-price-history (after 3 retries): Client error '403 Forbidden' for url 'https://www.macrotrends.net/stocks/charts/RY/royal-bank-of-canada/stock-price-history'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/403
# 2026-03-24 17:52:19,130 WARNING aieng.agent_evals.knowledge_qa.agent: Tool error: web_fetch failed - HTTP 403: Forbidden (failed after 3 retries)
# 2026-03-24 17:52:19,247 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 17:52:19,249 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 17:52:21,875 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 17:52:21,878 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: web_fetch({'query': 'closing price for S&P/TSX Canadian Financials Index on August 27, 2013 and August 30, 2013', 'url': 'https://ca.investing.com/indices/s-p-tsx-canadian-financials-historical-data'})
# 2026-03-24 17:52:22,526 INFO aieng.agent_evals.tools.web: Fetched 176550 chars from https://ca.investing.com/indices/s-p-tsx-canadian-financials-historical-data, extracting info...
# 2026-03-24 17:52:24,591 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: web_fetch completed
# 2026-03-24 17:52:24,711 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 17:52:24,713 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 17:52:27,852 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 17:52:27,856 INFO aieng.agent_evals.knowledge_qa.agent: Replanned with 3 new steps (keeping 4 completed)
# 2026-03-24 17:52:27,857 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'Canadian bank stocks S&P/TSX Financials Index performance August 27-30 2013 news report analysis'})
# 2026-03-24 17:52:27,967 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 17:52:38,816 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-24 17:52:38,934 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 17:52:38,935 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 17:52:43,646 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 17:52:43,693 WARNING langfuse: Propagated attribute 'experiment_item_metadata' value is over 200 characters (214 chars). Dropping value.
# 2026-03-24 17:52:58,942 WARNING langfuse: Propagated attribute 'experiment_item_metadata' value is over 200 characters (209 chars). Dropping value.
# 2026-03-24 17:52:59,093 INFO aieng.agent_evals.knowledge_qa.agent: Answering question: Did any of the Big Five Canadian banks announce layoffs in August 2013?...
# 2026-03-24 17:52:59,204 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 17:53:01,942 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 17:53:01,945 INFO aieng.agent_evals.knowledge_qa.agent: Extracted plan with 4 steps
# 2026-03-24 17:53:01,946 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'Big Five Canadian banks layoffs August 2013'})
# 2026-03-24 17:53:02,059 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 17:53:12,329 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-24 17:53:12,891 INFO google_adk.google.adk.models.gemini_context_cache_manager: Cache created successfully: cachedContents/lqvg1gfloyt9nrpw54y25eiydk5et8ji4nxm1h4f
# 2026-03-24 17:53:12,894 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 17:53:12,895 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 17:53:14,695 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 17:53:14,698 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: web_fetch({'query': 'Did BMO announce layoffs in August 2013? When were the job cuts announced?', 'url': 'https://www.cbc.ca/news/business/bmo-cut-1-000-jobs-in-last-quarter-1.2448862'})
# 2026-03-24 17:56:18,042 ERROR aieng.agent_evals.tools.web: Failed to fetch https://www.cbc.ca/news/business/bmo-cut-1-000-jobs-in-last-quarter-1.2448862 after 3 retries:
# 2026-03-24 17:56:18,045 WARNING aieng.agent_evals.knowledge_qa.agent: Tool error: web_fetch failed - Failed after 3 retries:
# 2026-03-24 17:56:18,158 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 17:56:18,160 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 17:56:19,355 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 17:56:19,358 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: web_fetch({'query': 'When did BMO announce the layoffs mentioned in this article, and when did the layoffs occur?', 'url': 'https://financialpost.com/news/fp-street/bmo-lays-off-nearly-1000-staff-in-fourth-quarter'})
# 2026-03-24 17:56:19,602 INFO aieng.agent_evals.tools.web: Fetched 105861 chars from https://financialpost.com/news/fp-street/bmo-lays-off-nearly-1000-staff-in-fourth-quarter, extracting info...
# 2026-03-24 17:56:22,878 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: web_fetch completed
# 2026-03-24 17:56:22,994 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 17:56:22,996 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 17:56:30,778 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 17:56:30,780 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'Big Five Canadian banks layoffs August 2013'})
# 2026-03-24 17:56:30,890 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 17:56:45,976 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-24 17:56:46,092 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 17:56:46,094 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 17:56:48,569 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 17:56:48,571 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: web_fetch({'url': 'http://m.tribune242.com/news/2013/nov/08/union-meets-cibc-bid-stop-lay-offs/', 'query': 'When were the discussions or plans for CIBC FirstCaribbean restructuring and potential redundancies first announced or reported?'})
# 2026-03-24 17:56:48,680 INFO aieng.agent_evals.tools.web: Fetched 3676 chars from http://m.tribune242.com/news/2013/nov/08/union-meets-cibc-bid-stop-lay-offs/, extracting info...
# 2026-03-24 17:56:51,854 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: web_fetch completed
# 2026-03-24 17:56:51,969 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 17:56:51,971 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 17:56:55,822 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 17:56:55,824 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'Big Five Canadian banks layoffs August 2013'})
# 2026-03-24 17:56:55,938 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 17:57:05,057 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-24 17:57:05,176 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 17:57:05,178 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 17:57:08,161 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 17:57:08,164 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: web_fetch({'query': 'When were the 1,000 job cuts announced by BMO?', 'url': 'https://www.cbc.ca/news/business/bmo-cut-1-000-jobs-in-last-quarter-1.2448862'})
# 2026-03-24 18:00:11,510 ERROR aieng.agent_evals.tools.web: Failed to fetch https://www.cbc.ca/news/business/bmo-cut-1-000-jobs-in-last-quarter-1.2448862 after 3 retries:
# 2026-03-24 18:00:11,513 WARNING aieng.agent_evals.knowledge_qa.agent: Tool error: web_fetch failed - Failed after 3 retries:
# 2026-03-24 18:00:11,630 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 18:00:11,632 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 18:00:13,296 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 18:00:13,300 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: web_fetch({'query': 'When were the BMO job cuts announced or reported in this article?', 'url': 'https://www.cbc.ca/news/business/bmo-job-cuts-have-little-to-do-with-sky-high-profits-1.2450825'})
# 2026-03-24 18:03:16,610 ERROR aieng.agent_evals.tools.web: Failed to fetch https://www.cbc.ca/news/business/bmo-job-cuts-have-little-to-do-with-sky-high-profits-1.2450825 after 3 retries:
# 2026-03-24 18:03:16,613 WARNING aieng.agent_evals.knowledge_qa.agent: Tool error: web_fetch failed - Failed after 3 retries:
# 2026-03-24 18:03:16,730 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 18:03:16,731 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 18:03:20,831 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 18:03:20,880 WARNING langfuse: Propagated attribute 'experiment_item_metadata' value is over 200 characters (209 chars). Dropping value.
# 2026-03-24 18:03:30,282 WARNING langfuse: Propagated attribute 'experiment_item_metadata' value is over 200 characters (215 chars). Dropping value.
# 2026-03-24 18:03:30,449 INFO aieng.agent_evals.knowledge_qa.agent: Answering question: What was BMO's provision for credit losses in Q3 2013 compared to Q2 2013?...
# 2026-03-24 18:03:30,567 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 18:03:34,759 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 18:03:34,761 INFO aieng.agent_evals.knowledge_qa.agent: Extracted plan with 4 steps
# 2026-03-24 18:03:34,762 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'BMO provision for credit losses Q3 2013 vs Q2 2013'})
# 2026-03-24 18:03:34,873 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 18:05:14,883 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7bf8504ca2d0 state=finished raised ReadTimeout>]
# 2026-03-24 18:05:14,891 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-24 18:05:15,558 INFO google_adk.google.adk.models.gemini_context_cache_manager: Cache created successfully: cachedContents/00zumh6cwtor4upvlwey4h9aqxf5qxaukdlfmdmp
# 2026-03-24 18:05:15,560 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 18:05:15,561 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 18:05:16,394 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 18:05:16,396 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'BMO Q3 2013 earnings report'})
# 2026-03-24 18:05:16,508 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 18:06:55,549 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7bf8606cfcb0 state=finished raised ReadTimeout>]
# 2026-03-24 18:06:55,551 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7bf85045f2f0 state=finished raised ReadTimeout>]
# 2026-03-24 18:06:55,553 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7bf8606ba6f0 state=finished raised ReadTimeout>]
# 2026-03-24 18:06:55,562 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7bf8606ce810 state=finished raised ReadTimeout>]
# 2026-03-24 18:06:55,570 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-24 18:06:55,688 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 18:06:55,690 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 18:06:56,575 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 18:06:56,577 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'BMO investor relations financial reports 2013'})
# 2026-03-24 18:06:56,687 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 18:08:35,937 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7bf8606295b0 state=finished raised ReadTimeout>]
# 2026-03-24 18:08:35,945 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7bf8606c49e0 state=finished raised ReadTimeout>]
# 2026-03-24 18:08:35,961 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7bf8606c4830 state=finished raised ReadTimeout>]
# 2026-03-24 18:08:35,967 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7bf85031b110 state=finished raised ReadTimeout>]
# 2026-03-24 18:08:35,988 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7bf850468f80 state=finished raised ReadTimeout>]
# 2026-03-24 18:08:35,996 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-24 18:08:36,119 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 18:08:36,121 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 18:08:37,109 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 18:08:37,112 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: web_fetch({'url': 'https://newsroom.bmo.com/2014-01-10-BMO-Financial-Group-2013-Annual-Report-Now-Available', 'query': 'provision for credit losses Q3 2013 and Q2 2013'})
# 2026-03-24 18:08:37,325 INFO aieng.agent_evals.tools.web: Fetched 27454 chars from https://newsroom.bmo.com/2014-01-10-BMO-Financial-Group-2013-Annual-Report-Now-Available, extracting info...
# 2026-03-24 18:08:38,982 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: web_fetch completed
# 2026-03-24 18:08:39,094 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 18:08:39,096 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 18:08:39,983 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 18:08:39,986 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'BMO Q3 2013 earnings report PDF'})
# 2026-03-24 18:08:40,103 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 18:10:17,370 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7bf86079ee40 state=finished raised ReadTimeout>]
# 2026-03-24 18:10:17,404 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7bf85031b7a0 state=finished raised ReadTimeout>]
# 2026-03-24 18:10:17,413 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-24 18:10:17,535 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 18:10:17,536 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 18:10:18,566 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 18:10:18,569 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'BMO investor relations quarterly reports 2013'})
# 2026-03-24 18:10:18,686 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 18:11:58,067 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7bf850304590 state=finished raised ReadTimeout>]
# 2026-03-24 18:11:58,116 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7bf8502046e0 state=finished raised ReadTimeout>]
# 2026-03-24 18:11:58,163 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7bf850307590 state=finished raised ReadTimeout>]
# 2026-03-24 18:11:58,198 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7bf86724a990 state=finished raised ReadTimeout>]
# 2026-03-24 18:11:58,223 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7bf85044dbb0 state=finished raised ReadTimeout>]
# 2026-03-24 18:11:58,231 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7bf8606beba0 state=finished raised ReadTimeout>]
# 2026-03-24 18:11:58,233 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7bf8501fc650 state=finished raised ReadTimeout>]
# 2026-03-24 18:11:58,239 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7bf850311d60 state=finished raised ReadTimeout>]
# 2026-03-24 18:11:58,251 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7bf85031af90 state=finished raised ReadTimeout>]
# 2026-03-24 18:11:58,270 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7bf850312ae0 state=finished raised ReadTimeout>]
# 2026-03-24 18:11:58,280 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7bf8606cb950 state=finished raised ReadTimeout>]
# 2026-03-24 18:11:58,304 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7bf8504f7500 state=finished raised ReadTimeout>]
# 2026-03-24 18:11:58,311 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-24 18:11:58,429 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 18:11:58,430 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 18:11:59,597 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 18:11:59,599 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'BMO Investor Relations Financial Information'})
# 2026-03-24 18:11:59,712 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 18:13:41,677 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7bf8606c8f20 state=finished raised ReadTimeout>]
# 2026-03-24 18:13:41,679 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7bf850217710 state=finished raised ReadTimeout>]
# 2026-03-24 18:13:41,681 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7bf8606cbb00 state=finished raised ReadTimeout>]
# 2026-03-24 18:13:41,690 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7bf8502142c0 state=finished raised ReadTimeout>]
# 2026-03-24 18:13:41,733 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7bf850207d70 state=finished raised ReadTimeout>]
# 2026-03-24 18:13:41,744 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-24 18:13:41,864 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 18:13:41,866 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 18:13:42,989 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 18:13:42,993 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'BMO Investor Relations historical financial reports 2013'})
# 2026-03-24 18:13:43,106 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 18:15:22,736 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7bf850256480 state=finished raised ReadTimeout>]
# 2026-03-24 18:15:22,737 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7bf850256ab0 state=finished raised ReadTimeout>]
# 2026-03-24 18:15:22,740 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7bf850261f10 state=finished raised ReadTimeout>]
# 2026-03-24 18:15:22,741 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7bf8606c1460 state=finished raised ReadTimeout>]
# 2026-03-24 18:15:22,749 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-24 18:15:22,870 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 18:15:22,871 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 18:15:24,172 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 18:15:24,175 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'site:bmo.com/investorrelations BMO Q3 2013 Report to Shareholders'})
# 2026-03-24 18:15:24,295 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 18:17:03,079 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7bf850217fe0 state=finished raised ReadTimeout>]
# 2026-03-24 18:17:03,080 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7bf8502157c0 state=finished raised ReadTimeout>]
# 2026-03-24 18:17:03,082 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7bf8504677d0 state=finished raised ReadTimeout>]
# 2026-03-24 18:17:03,092 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-24 18:17:03,214 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 18:17:03,216 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 18:17:04,462 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 18:17:04,465 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'BMO 2013 Third Quarter Report to Shareholders PDF'})
# 2026-03-24 18:17:04,574 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# ...
# 2026-03-24 19:51:01,807 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 19:51:03,156 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 19:51:03,159 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: web_fetch({'query': "Impact of ING Direct and Credito Familiar acquisitions on Scotiabank's Q3 2013 consumer lending", 'url': 'https://www.scotiabank.com/ca/en/files/13/12/BNS_2013_Annual_Report.pdf'})
# 2026-03-24 19:51:04,285 INFO aieng.agent_evals.tools.web: Extracted 28497 chars from PDF (200 pages), extracting info...
# 2026-03-24 19:51:07,743 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: web_fetch completed
# 2026-03-24 19:51:07,867 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 19:51:07,869 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 19:51:09,374 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 19:51:09,376 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'Scotiabank Q3 2013 earnings call transcript ING Direct Credito Familiar consumer lending'})
# 2026-03-24 19:51:09,486 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 19:51:23,463 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-24 19:51:23,575 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 19:51:23,577 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 19:51:26,863 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 19:51:26,906 WARNING langfuse: Propagated attribute 'experiment_item_metadata' value is over 200 characters (251 chars). Dropping value.
# 2026-03-24 19:51:34,575 WARNING langfuse: Propagated attribute 'experiment_item_metadata' value is over 200 characters (240 chars). Dropping value.
# 2026-03-24 19:51:34,725 INFO aieng.agent_evals.knowledge_qa.agent: Answering question: What was Bank of Montreal's Q3 2013 net income and how did it compare to the prior year?...
# 2026-03-24 19:51:34,855 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 19:51:38,026 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 19:51:38,029 INFO aieng.agent_evals.knowledge_qa.agent: Extracted plan with 4 steps
# 2026-03-24 19:51:38,030 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'Bank of Montreal Q3 2013 net income'})
# 2026-03-24 19:51:38,140 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 19:53:15,722 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7bf8504682c0 state=finished raised ReadTimeout>]
# 2026-03-24 19:53:15,732 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7bf8607d1f70 state=finished raised ReadTimeout>]
# 2026-03-24 19:53:15,742 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-24 19:53:16,494 INFO google_adk.google.adk.models.gemini_context_cache_manager: Cache created successfully: cachedContents/emvof3wjnueolpn34bs1xxf9o0wwlrrh2xc7fi7q
# 2026-03-24 19:53:16,497 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 19:53:16,498 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 19:53:17,602 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 19:53:17,605 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'Bank of Montreal Q3 2013 earnings press release'})
# 2026-03-24 19:53:17,711 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 19:55:01,666 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7bf850245b50 state=finished raised ReadTimeout>]
# 2026-03-24 19:55:01,674 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-24 19:55:01,793 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 19:55:01,795 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 19:55:03,027 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 19:55:03,029 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'BMO investor relations Q3 2013 results'})
# 2026-03-24 19:55:03,142 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 19:56:52,269 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7bf8502173e0 state=finished raised ReadTimeout>]
# 2026-03-24 19:56:52,363 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7bf850204aa0 state=finished raised ReadTimeout>]
# 2026-03-24 19:56:52,373 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-24 19:56:52,487 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 19:56:52,489 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 19:56:54,069 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 19:56:54,072 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'Bank of Montreal Q3 2013 Report to Shareholders SEDAR'})
# 2026-03-24 19:56:54,179 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 19:58:32,093 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7bf850111970 state=finished raised ReadTimeout>]
# 2026-03-24 19:58:32,123 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7bf850111a30 state=finished raised ReadTimeout>]
# 2026-03-24 19:58:32,130 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-24 19:58:32,249 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 19:58:32,251 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 19:58:33,586 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 19:58:33,589 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: web_fetch({'query': 'Bank of Montreal net income for Q3 2013 and Q3 2012', 'url': 'https://www.sec.gov/Archives/edgar/data/927971/000119312516786447/d252647dex992.htm'})
# 2026-03-24 19:58:35,349 INFO aieng.agent_evals.tools.web: Fetched 200035 chars from https://www.sec.gov/Archives/edgar/data/927971/000119312516786447/d252647dex992.htm, extracting info...
# 2026-03-24 19:58:39,498 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: web_fetch completed
# 2026-03-24 19:58:39,608 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 19:58:39,610 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 19:58:40,934 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 19:58:40,937 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'Bank of Montreal Q3 2012 net income'})
# 2026-03-24 19:58:41,049 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 20:00:18,788 WARNING aieng.agent_evals.tools._redirect: Failed to resolve redirect URL https://vertexaisearch.cloud.google.com/grounding-api-redire...: RetryError: RetryError[<Future at 0x7bf82c1589e0 state=finished raised ReadTimeout>]
# 2026-03-24 20:00:18,797 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-24 20:00:18,909 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 20:00:18,911 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 20:00:21,374 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 20:00:21,377 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: web_fetch({'query': 'Bank of Montreal Q3 2012 net income and comparison to prior year', 'url': 'https://toronto.citynews.ca/2012/08/28/bank-of-montreal-profits-rise-to-970-million-in-third-quarter-revenue-higher/'})
# 2026-03-24 20:00:23,187 INFO aieng.agent_evals.tools.web: Fetched 17913 chars from https://toronto.citynews.ca/2012/08/28/bank-of-montreal-profits-rise-to-970-million-in-third-quarter-revenue-higher/, extracting info...
# 2026-03-24 20:00:25,008 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: web_fetch completed
# 2026-03-24 20:00:25,121 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 20:00:25,122 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 20:00:29,834 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 20:00:29,883 WARNING langfuse: Propagated attribute 'experiment_item_metadata' value is over 200 characters (240 chars). Dropping value.
# 2026-03-24 20:00:45,171 WARNING langfuse: Propagated attribute 'experiment_item_metadata' value is over 200 characters (241 chars). Dropping value.
# 2026-03-24 20:00:45,335 INFO aieng.agent_evals.knowledge_qa.agent: Answering question: Why did Toronto-Dominion Bank's profit fall in Q3 2013?...
# 2026-03-24 20:00:45,447 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 20:00:49,118 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 20:00:49,121 INFO aieng.agent_evals.knowledge_qa.agent: Extracted plan with 4 steps
# 2026-03-24 20:00:49,122 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'Toronto-Dominion Bank profit fall Q3 2013'})
# 2026-03-24 20:00:49,229 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 20:00:52,586 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-24 20:00:53,078 INFO google_adk.google.adk.models.gemini_context_cache_manager: Cache created successfully: cachedContents/wkz43n8p06uasky4z2wsh8o8u3atvqzx1xs4hz0j
# 2026-03-24 20:00:53,081 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 20:00:53,082 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 20:00:54,355 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 20:00:54,357 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: web_fetch({'query': 'reasons for profit fall in Q3 2013, specifically mentioning insurance charges or other factors', 'url': 'https://www.td.com/content/dam/tdcom/canada/about-td/pdf/quarterly-results/2013/2013-Q3-Transcript_Final_E.pdf'})
# 2026-03-24 20:00:54,852 INFO aieng.agent_evals.tools.web: Extracted 34649 chars from PDF (18 pages), extracting info...
# 2026-03-24 20:00:59,018 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: web_fetch completed
# 2026-03-24 20:00:59,127 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 20:00:59,128 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 20:01:00,900 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 20:01:00,942 WARNING langfuse: Propagated attribute 'experiment_item_metadata' value is over 200 characters (241 chars). Dropping value.
# 2026-03-24 20:01:20,454 WARNING langfuse: Propagated attribute 'experiment_item_metadata' value is over 200 characters (237 chars). Dropping value.
# 2026-03-24 20:01:20,630 INFO aieng.agent_evals.knowledge_qa.agent: Answering question: What was Royal Bank of Canada's Q3 2013 net income?...
# 2026-03-24 20:01:20,744 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 20:01:23,467 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 20:01:23,470 INFO aieng.agent_evals.knowledge_qa.agent: Extracted plan with 4 steps
# 2026-03-24 20:01:23,471 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: google_search({'query': 'Royal Bank of Canada Q3 2013 net income'})
# 2026-03-24 20:01:23,582 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 20:01:27,230 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: google_search completed
# 2026-03-24 20:01:27,871 INFO google_adk.google.adk.models.gemini_context_cache_manager: Cache created successfully: cachedContents/62iq6pune5vgtafyusdi6vgjq0mqfvd82vdohwyq
# 2026-03-24 20:01:27,874 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 20:01:27,876 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 20:01:29,117 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 20:01:29,120 INFO aieng.agent_evals.knowledge_qa.agent: Tool call: web_fetch({'url': 'https://www.rbc.com/investor-relations/_assets-custom/pdf/q32013report.pdf', 'query': 'Royal Bank of Canada Q3 2013 net income'})
# 2026-03-24 20:01:29,780 INFO aieng.agent_evals.tools.web: Extracted 49112 chars from PDF (80 pages), extracting info...
# 2026-03-24 20:01:32,455 INFO aieng.agent_evals.knowledge_qa.agent: Tool response: web_fetch completed
# 2026-03-24 20:01:32,571 INFO google_adk.google.adk.models.google_llm: Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2026-03-24 20:01:32,572 INFO google_genai.models: AFC is enabled with max remote calls: 10.
# 2026-03-24 20:01:33,768 INFO google_adk.google.adk.models.google_llm: Response received from the model.
# 2026-03-24 20:01:33,812 WARNING langfuse: Propagated attribute 'experiment_item_metadata' value is over 200 characters (237 chars). Dropping value.
# ✓ Experiment complete
# <p>View experiment: <a href="https://us.cloud.langfuse.com/project/cmlsfuxvf017rad077ro3bqq2/datasets/cmn4rzi8y02wvad075c8rautl/runs/792eca4c-78a1-4a7e-b0f3-e5cea013a655" target="_blank">https://us.cloud.langfuse.com/project/cmlsfuxvf017rad077ro3bqq2/datasets/cmn4rzi8y02wvad075c8rautl/runs/792eca4c-78a1-4a7e-b0f3-e5cea013a655</a></p>

# %% [markdown]
# ## 4. Inspecting Results
#
# The `ExperimentResult` object gives programmatic access to every item-level score.
# Aggregate metrics are visible in the Langfuse experiment run summary in the UI.

# %%
rows = []
for item_result in experiment_result.item_results:
    item = item_result.item
    question = str(item.input)
    row = {
        "question": question[:55] + "..." if len(question) > 55 else question,
        "answer_type": (item.metadata or {}).get("answer_type", ""),
    }
    for evaluation in item_result.evaluations or []:
        row[evaluation.name] = evaluation.value
    rows.append(row)

df = pd.DataFrame(rows)
print(df.to_string(index=False))

# %%
# Mean of numeric metrics
numeric_cols = [c for c in ["F1", "Precision", "Recall"] if c in df.columns]
if numeric_cols:
    means_table = Table(title="Mean Scores")
    means_table.add_column("Metric", style="cyan")
    means_table.add_column("Mean", style="white")
    for col in numeric_cols:
        means_table.add_row(col, f"{df[col].mean():.3f}")
    console.print(means_table)

# Outcome distribution
if "Outcome" in df.columns:
    outcome_table = Table(title="Outcome Distribution")
    outcome_table.add_column("Outcome", style="cyan")
    outcome_table.add_column("Count", style="white", justify="right")
    outcome_table.add_column("Fraction", style="dim", justify="right")
    total = len(df)
    for outcome, count in df["Outcome"].value_counts().items():
        outcome_table.add_row(str(outcome), str(count), f"{count / total:.0%}")
    console.print(outcome_table)

# %% [markdown]
# ## 5. Iterating on the Agent
#
# The dataset in Langfuse is persistent — you don't need to re-upload it. To evaluate a modified
# agent, call `run_experiment` again with a new `name` argument. Langfuse will create a new
# experiment run and you can compare runs side-by-side in the UI.
#
# ### Levers to Explore
#
# - **System prompt** — edit `SYSTEM_INSTRUCTIONS_TEMPLATE` in `system_instructions.py` to change
#   the search strategy, verification rules, or final answer format
# - **Planning** — toggle `enable_planning=False` to skip PlanReAct and compare quality vs. speed
# - **Model** — change the Gemini model in `KnowledgeGroundedAgent` for different capability/cost trade-offs
# - **Dataset** — change the `category` filter in Section 1 or increase `samples` to cover more examples
#
# ### What to Look for in Langfuse
#
# - Items with **low F1** — did the agent fail to fetch the source? Stop early? Misread the question?
# - Items with **`correct_with_extraneous`** — is the agent over-generating? Can the prompt be tightened?
# - **Latency outliers** — which steps are slow? Is replanning happening unnecessarily?

# %% [markdown]
# ## Summary
#
# In this notebook you:
#
# 1. **Uploaded** a DeepSearchQA subset to Langfuse as a persistent, reusable dataset
# 2. **Understood** the LLM-as-judge grader: precision, recall, F1, and the four outcome categories
# 3. **Walked through** a single-sample evaluation end-to-end
# 4. **Ran** a full experiment with `run_experiment` and inspected item-level scores
# 5. **Learned** how to iterate: re-run with a new experiment name to compare configurations in Langfuse
#
# The evaluation pipeline is the foundation for systematic agent improvement — each iteration
# produces a new experiment run that you can compare to the baseline in the Langfuse UI.

# %%
console.print(Panel("[green]✓[/green] Notebook complete!", title="Done", border_style="green"))
if experiment_result.dataset_run_url:
    display(
        HTML(
            f'<p>View experiment results: <a href="{experiment_result.dataset_run_url}" target="_blank">{experiment_result.dataset_run_url}</a></p>'
        )
    )
